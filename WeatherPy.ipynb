# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 647

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0089b060fc68e7a641e9237dab69fbc2

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0089b060fc68e7a641e9237dab69fbc2&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | port elizabeth
# Processing Record 2 of Set 13 | rikitea
# Processing Record 3 of Set 13 | kirakira
# Processing Record 4 of Set 13 | vaini
# Processing Record 5 of Set 13 | inuvik
# Processing Record 6 of Set 13 | bethel
# Processing Record 7 of Set 13 | ribeira grande
# Processing Record 8 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 13 | tiznit
# Processing Record 10 of Set 13 | pascagoula
# Processing Record 11 of Set 13 | valle hermoso
# Processing Record 12 of Set 13 | chokurdakh
# Processing Record 13 of Set 13 | edd
# Processing Record 14 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 13 | neiafu
# Processing Record 16 of Set 13 | pemangkat
# Processing Record 17 of Set 13 | hithadhoo
# Processing Record 18 of Set 13 | jamestown
# Processing Record 19 of Set 13 | saint-augustin
# Processing Record 20 of Set 13 | pisco
# Processing Record 21 of Set 13 | grindavik
# Processing Record 22 of Set 13 | necochea
# Processing Record 23 of Set 13 | codrington
# Processing Record 24 of Set 13 | kadoma
# Processing Record 25 of Set 13 | cape town
# Processing Record 26 of Set 13 | airai
# Processing Record 27 of Set 13 | dzilam gonzalez
# Processing Record 28 of Set 13 | bathurst
# Processing Record 29 of Set 13 | pitimbu
# Processing Record 30 of Set 13 | kaitong
# Processing Record 31 of Set 13 | mount isa
# Processing Record 32 of Set 13 | punta arenas
# Processing Record 33 of Set 13 | santa maria
# Processing Record 34 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 13 | saint-philippe
# Processing Record 36 of Set 13 | arraial do cabo
# Processing Record 37 of Set 13 | chapais
# Processing Record 38 of Set 13 | marfino
# Processing Record 39 of Set 13 | khatanga
# Processing Record 40 of Set 13 | faanui
# Processing Record 41 of Set 13 | tuktoyaktuk
# Processing Record 42 of Set 13 | lata
# Processing Record 43 of Set 13 | glasgow
# Processing Record 44 of Set 13 | micheweni
# Processing Record 45 of Set 13 | cidreira
# Processing Record 46 of Set 13 | salym
# Processing Record 47 of Set 13 | busselton
# Processing Record 48 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 49 of Set 13 | pochutla
# Processing Record 50 of Set 13 | kantang
# Processing Record 1 of Set 14 | marienburg
# Processing Record 2 of Set 14 | bilma
# Processing Record 3 of Set 14 | bubaque
# Processing Record 4 of Set 14 | alice springs
# Processing Record 5 of Set 14 | ushuaia
# Processing Record 6 of Set 14 | castro
# Processing Record 7 of Set 14 | mangan
# Processing Record 8 of Set 14 | labuhan
# Processing Record 9 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 10 of Set 14 | port macquarie
# Processing Record 11 of Set 14 | esperance
# Processing Record 12 of Set 14 | mahebourg
# Processing Record 13 of Set 14 | yerbogachen
# Processing Record 14 of Set 14 | upernavik
# Processing Record 15 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 14 | itoman
# Processing Record 17 of Set 14 | albany
# Processing Record 18 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 14 | nikolskoye
# Processing Record 20 of Set 14 | waipawa
# Processing Record 21 of Set 14 | north marysville
# City not found. Skipping...
# Processing Record 22 of Set 14 | muros
# Processing Record 23 of Set 14 | odweyne
# Processing Record 24 of Set 14 | takhatgarh
# Processing Record 25 of Set 14 | harper
# Processing Record 26 of Set 14 | lamar
# Processing Record 27 of Set 14 | provideniya
# Processing Record 28 of Set 14 | tura
# Processing Record 29 of Set 14 | canita
# Processing Record 30 of Set 14 | verkhoyansk
# Processing Record 31 of Set 14 | port alfred
# Processing Record 32 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 14 | kapaa
# Processing Record 34 of Set 14 | puerto narino
# Processing Record 35 of Set 14 | mataura
# Processing Record 36 of Set 14 | kaitangata
# Processing Record 37 of Set 14 | ahipara
# Processing Record 38 of Set 14 | ketchikan
# Processing Record 39 of Set 14 | kodiak
# Processing Record 40 of Set 14 | ponta do sol
# Processing Record 41 of Set 14 | huarmey
# Processing Record 42 of Set 14 | asfi
# Processing Record 43 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 14 | riyadh
# Processing Record 45 of Set 14 | davidson
# Processing Record 46 of Set 14 | avarua
# Processing Record 47 of Set 14 | rawson
# Processing Record 48 of Set 14 | manggar
# Processing Record 49 of Set 14 | puerto ayora
# Processing Record 50 of Set 14 | qaqortoq
# Processing Record 1 of Set 15 | tiksi
# Processing Record 2 of Set 15 | saskylakh
# Processing Record 3 of Set 15 | dingle
# Processing Record 4 of Set 15 | port lincoln
# Processing Record 5 of Set 15 | cap malheureux
# Processing Record 6 of Set 15 | chuy
# Processing Record 7 of Set 15 | lebu
# Processing Record 8 of Set 15 | merritt island
# Processing Record 9 of Set 15 | san rafael
# Processing Record 10 of Set 15 | cubara
# Processing Record 11 of Set 15 | hobart
# Processing Record 12 of Set 15 | victoria
# Processing Record 13 of Set 15 | bredasdorp
# Processing Record 14 of Set 15 | trinidad
# Processing Record 15 of Set 15 | hilo
# Processing Record 16 of Set 15 | hermanus
# Processing Record 17 of Set 15 | narsaq
# Processing Record 18 of Set 15 | gewane
# Processing Record 19 of Set 15 | georgetown
# Processing Record 20 of Set 15 | eenhana
# Processing Record 21 of Set 15 | adrar
# Processing Record 22 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 15 | denpasar
# Processing Record 24 of Set 15 | los llanos de aridane
# Processing Record 25 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 15 | sao jose da coroa grande
# Processing Record 27 of Set 15 | lorengau
# Processing Record 28 of Set 15 | iqaluit
# Processing Record 29 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 15 | new norfolk
# Processing Record 31 of Set 15 | katima mulilo
# Processing Record 32 of Set 15 | akdepe
# Processing Record 33 of Set 15 | south charleston
# Processing Record 34 of Set 15 | baykit
# Processing Record 35 of Set 15 | te anau
# Processing Record 36 of Set 15 | naze
# Processing Record 37 of Set 15 | surt
# Processing Record 38 of Set 15 | wangaratta
# Processing Record 39 of Set 15 | buraydah
# Processing Record 40 of Set 15 | port angeles
# Processing Record 41 of Set 15 | port pirie
# Processing Record 42 of Set 15 | east london
# Processing Record 43 of Set 15 | kloulklubed
# Processing Record 44 of Set 15 | beloha
# Processing Record 45 of Set 15 | kavaratti
# Processing Record 46 of Set 15 | barrow
# Processing Record 47 of Set 15 | mercedes
# Processing Record 48 of Set 15 | imphal
# Processing Record 49 of Set 15 | tecoanapa
# Processing Record 50 of Set 15 | uruzgan
# Processing Record 1 of Set 16 | yarega
# Processing Record 2 of Set 16 | robore
# Processing Record 3 of Set 16 | pirai do sul
# Processing Record 4 of Set 16 | havoysund
# Processing Record 5 of Set 16 | mamallapuram
# Processing Record 6 of Set 16 | cherskiy
# Processing Record 7 of Set 16 | lima
# Processing Record 8 of Set 16 | gurupi
# Processing Record 9 of Set 16 | dapdap
# Processing Record 10 of Set 16 | khandbari
# Processing Record 11 of Set 16 | krasnokholmskiy
# Processing Record 12 of Set 16 | kenai
# Processing Record 13 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 16 | hofn
# Processing Record 15 of Set 16 | ugoofaaru
# Processing Record 16 of Set 16 | fairbanks
# Processing Record 17 of Set 16 | atuona
# Processing Record 18 of Set 16 | sorland
# Processing Record 19 of Set 16 | mayo
# Processing Record 20 of Set 16 | houston
# Processing Record 21 of Set 16 | waitara
# Processing Record 22 of Set 16 | yashkul
# Processing Record 23 of Set 16 | brae
# Processing Record 24 of Set 16 | inirida
# Processing Record 25 of Set 16 | yellowknife
# Processing Record 26 of Set 16 | half moon bay
# Processing Record 27 of Set 16 | acapulco
# Processing Record 28 of Set 16 | dunedin
# Processing Record 29 of Set 16 | sorso
# Processing Record 30 of Set 16 | bonthe
# Processing Record 31 of Set 16 | luderitz
# Processing Record 32 of Set 16 | slave lake
# Processing Record 33 of Set 16 | butaritari
# Processing Record 34 of Set 16 | avera
# Processing Record 35 of Set 16 | naron
# Processing Record 36 of Set 16 | beringovskiy
# Processing Record 37 of Set 16 | verkhovye
# Processing Record 38 of Set 16 | takaka
# Processing Record 39 of Set 16 | pangnirtung
# Processing Record 40 of Set 16 | selje
# Processing Record 41 of Set 16 | richards bay
# Processing Record 42 of Set 16 | cabo san lucas
# Processing Record 43 of Set 16 | bambous virieux
# Processing Record 44 of Set 16 | port hardy
# Processing Record 45 of Set 16 | anjozorobe
# Processing Record 46 of Set 16 | mar del plata
# Processing Record 47 of Set 16 | carnarvon
# Processing Record 48 of Set 16 | college
# Processing Record 49 of Set 16 | thompson
# Processing Record 50 of Set 16 | deputatskiy
# Processing Record 1 of Set 17 | salinas
# Processing Record 2 of Set 17 | hasaki
# Processing Record 3 of Set 17 | samarai
# Processing Record 4 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 17 | celestun
# Processing Record 6 of Set 17 | katsuura
# Processing Record 7 of Set 17 | vryburg
# Processing Record 8 of Set 17 | longyearbyen
# Processing Record 9 of Set 17 | aitape
# Processing Record 10 of Set 17 | tambura
# Processing Record 11 of Set 17 | hohhot
# Processing Record 12 of Set 17 | bluff
# Processing Record 13 of Set 17 | aksay
# Processing Record 14 of Set 17 | sidney
# Processing Record 15 of Set 17 | olean
# Processing Record 16 of Set 17 | monrovia
# Processing Record 17 of Set 17 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 17 | nguru
# Processing Record 19 of Set 17 | qui nhon
# Processing Record 20 of Set 17 | blonduos
# City not found. Skipping...
# Processing Record 21 of Set 17 | cacequi
# Processing Record 22 of Set 17 | tasiilaq
# Processing Record 23 of Set 17 | boulsa
# Processing Record 24 of Set 17 | kwinana
# Processing Record 25 of Set 17 | soyo
# Processing Record 26 of Set 17 | liniere
# City not found. Skipping...
# Processing Record 27 of Set 17 | acajutla
# Processing Record 28 of Set 17 | rio gallegos
# Processing Record 29 of Set 17 | rio de jesus
# Processing Record 30 of Set 17 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 17 | oussouye
# Processing Record 32 of Set 17 | iquique
# Processing Record 33 of Set 17 | jahrom
# City not found. Skipping...
# Processing Record 34 of Set 17 | gaoual
# Processing Record 35 of Set 17 | sorong
# Processing Record 36 of Set 17 | gat
# Processing Record 37 of Set 17 | hrodna
# Processing Record 38 of Set 17 | marystown
# Processing Record 39 of Set 17 | lyons
# Processing Record 40 of Set 17 | cuitzeo
# Processing Record 41 of Set 17 | hervey bay
# Processing Record 42 of Set 17 | bud
# Processing Record 43 of Set 17 | ilulissat
# Processing Record 44 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 17 | sidi qasim
# City not found. Skipping...
# Processing Record 46 of Set 17 | kavieng
# Processing Record 47 of Set 17 | kahului
# Processing Record 48 of Set 17 | asbe teferi
# Processing Record 49 of Set 17 | ancud
# Processing Record 50 of Set 17 | kawana waters
# City not found. Skipping...
# Processing Record 1 of Set 18 | clyde river
# Processing Record 2 of Set 18 | quartucciu
# Processing Record 3 of Set 18 | prince rupert
# Processing Record 4 of Set 18 | gravelbourg
# Processing Record 5 of Set 18 | byron bay
# Processing Record 6 of Set 18 | mabay
# Processing Record 7 of Set 18 | leningradskiy
# Processing Record 8 of Set 18 | vila franca do campo
# Processing Record 9 of Set 18 | khoy
# Processing Record 10 of Set 18 | bluefields
# Processing Record 11 of Set 18 | dikson
# Processing Record 12 of Set 18 | sungaipenuh
# Processing Record 13 of Set 18 | saint george
# Processing Record 14 of Set 18 | la paz
# Processing Record 15 of Set 18 | amahai
# Processing Record 16 of Set 18 | san patricio
# Processing Record 17 of Set 18 | tonstad
# Processing Record 18 of Set 18 | anaconda
# Processing Record 19 of Set 18 | zhuanghe
# Processing Record 20 of Set 18 | jinka
# Processing Record 21 of Set 18 | flin flon
# Processing Record 22 of Set 18 | huangzhou
# Processing Record 23 of Set 18 | tshikapa
# Processing Record 24 of Set 18 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 18 | torbay
# Processing Record 26 of Set 18 | porto novo
# Processing Record 27 of Set 18 | great yarmouth
# Processing Record 28 of Set 18 | manicore
# Processing Record 29 of Set 18 | broken hill
# Processing Record 30 of Set 18 | udachnyy
# Processing Record 31 of Set 18 | mabai
# Processing Record 32 of Set 18 | tsiroanomandidy
# Processing Record 33 of Set 18 | anadyr
# Processing Record 34 of Set 18 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 18 | hovd
# Processing Record 36 of Set 18 | qaanaaq
# Processing Record 37 of Set 18 | vanavara
# Processing Record 38 of Set 18 | yeppoon
# Processing Record 39 of Set 18 | sinnamary
# Processing Record 40 of Set 18 | severo-kurilsk
# Processing Record 41 of Set 18 | broome
# Processing Record 42 of Set 18 | wattegama
# Processing Record 43 of Set 18 | lompoc
# Processing Record 44 of Set 18 | korla
# Processing Record 45 of Set 18 | malpur
# Processing Record 46 of Set 18 | cassilandia
# Processing Record 47 of Set 18 | ondjiva
# Processing Record 48 of Set 18 | poum
# Processing Record 49 of Set 18 | vilhena
# Processing Record 50 of Set 18 | yar-sale
# Processing Record 1 of Set 19 | tacoronte
# Processing Record 2 of Set 19 | cayenne
# Processing Record 3 of Set 19 | shenjiamen
# Processing Record 4 of Set 19 | norman wells
# Processing Record 5 of Set 19 | bowen
# Processing Record 6 of Set 19 | sioux lookout
# Processing Record 7 of Set 19 | jieshi
# Processing Record 8 of Set 19 | veseloyarsk
# Processing Record 9 of Set 19 | vanderhoof
# Processing Record 10 of Set 19 | praia da vitoria
# Processing Record 11 of Set 19 | temaraia
# City not found. Skipping...
# Processing Record 12 of Set 19 | taoudenni
# Processing Record 13 of Set 19 | caraballeda
# Processing Record 14 of Set 19 | camacha
# Processing Record 15 of Set 19 | snasa
# Processing Record 16 of Set 19 | lucapa
# Processing Record 17 of Set 19 | barabinsk
# Processing Record 18 of Set 19 | kopychyntsi
# Processing Record 19 of Set 19 | cairns
# Processing Record 20 of Set 19 | saint-louis
# Processing Record 21 of Set 19 | padang
# Processing Record 22 of Set 19 | chapayevka
# Processing Record 23 of Set 19 | benguela
# Processing Record 24 of Set 19 | kamenka
# Processing Record 25 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 19 | nuuk
# Processing Record 27 of Set 19 | makakilo city
# Processing Record 28 of Set 19 | mitu
# Processing Record 29 of Set 19 | hambantota
# Processing Record 30 of Set 19 | caravelas
# Processing Record 31 of Set 19 | phan thiet
# Processing Record 32 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 19 | chernolesskoye
# Processing Record 34 of Set 19 | havre-saint-pierre
# Processing Record 35 of Set 19 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 19 | alekseyevka
# Processing Record 37 of Set 19 | esqueda
# Processing Record 38 of Set 19 | volklingen
# Processing Record 39 of Set 19 | pevek
# Processing Record 40 of Set 19 | jumla
# Processing Record 41 of Set 19 | namatanai
# Processing Record 42 of Set 19 | srednekolymsk
# Processing Record 43 of Set 19 | mount gambier
# Processing Record 44 of Set 19 | andenes
# Processing Record 45 of Set 19 | kuopio
# Processing Record 46 of Set 19 | nichinan
# Processing Record 47 of Set 19 | coos bay
# Processing Record 48 of Set 19 | bengkulu
# Processing Record 49 of Set 19 | dumas
# Processing Record 50 of Set 19 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 20 | nanakuli
# Processing Record 2 of Set 20 | bari sadri
# Processing Record 3 of Set 20 | terrace
# Processing Record 4 of Set 20 | urubicha
# Processing Record 5 of Set 20 | laguna
# Processing Record 6 of Set 20 | husavik
# Processing Record 7 of Set 20 | cockburn harbour
# City not found. Skipping...
# Processing Record 8 of Set 20 | preston
# Processing Record 9 of Set 20 | tsivilsk
# Processing Record 10 of Set 20 | shache
# Processing Record 11 of Set 20 | roswell
# Processing Record 12 of Set 20 | amalapuram
# Processing Record 13 of Set 20 | saldanha
# Processing Record 14 of Set 20 | atar
# Processing Record 15 of Set 20 | tanout
# Processing Record 16 of Set 20 | agrafa
# Processing Record 17 of Set 20 | bathsheba
# Processing Record 18 of Set 20 | maldonado
# Processing Record 19 of Set 20 | yantal
# Processing Record 20 of Set 20 | safaga
# Processing Record 21 of Set 20 | aleksandrovsk
# Processing Record 22 of Set 20 | fomboni
# Processing Record 23 of Set 20 | jalu
# Processing Record 24 of Set 20 | sokolo
# Processing Record 25 of Set 20 | dilla
# Processing Record 26 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 20 | igarka
# Processing Record 28 of Set 20 | manadhoo
# Processing Record 29 of Set 20 | ust-maya
# Processing Record 30 of Set 20 | abu samrah
# Processing Record 31 of Set 20 | taksimo
# Processing Record 32 of Set 20 | calbuco
# Processing Record 33 of Set 20 | gao
# Processing Record 34 of Set 20 | kutulik
# Processing Record 35 of Set 20 | sabha
# Processing Record 36 of Set 20 | ejigbo
# Processing Record 37 of Set 20 | talnakh
# Processing Record 38 of Set 20 | fujieda
# Processing Record 39 of Set 20 | vaitape
# Processing Record 40 of Set 20 | sungai siput utara
# City not found. Skipping...
# Processing Record 41 of Set 20 | tynda
# Processing Record 42 of Set 20 | karratha
# Processing Record 43 of Set 20 | palauig
# Processing Record 44 of Set 20 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 20 | rumoi
# Processing Record 46 of Set 20 | rohatyn
# Processing Record 47 of Set 20 | chimoio
# Processing Record 48 of Set 20 | jaciara
# Processing Record 49 of Set 20 | kimbe
# Processing Record 50 of Set 20 | kot putli
# City not found. Skipping...
# Processing Record 1 of Set 21 | kuching
# Processing Record 2 of Set 21 | kyzyl-suu
# Processing Record 3 of Set 21 | ocos
# Processing Record 4 of Set 21 | manuk mangkaw
# Processing Record 5 of Set 21 | kyabe
# Processing Record 6 of Set 21 | zbarazh
# Processing Record 7 of Set 21 | verkhnetulomskiy
# Processing Record 8 of Set 21 | lagoa
# Processing Record 9 of Set 21 | takoradi
# Processing Record 10 of Set 21 | mnogovershinnyy
# Processing Record 11 of Set 21 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 21 | vardo
# Processing Record 13 of Set 21 | kitui
# Processing Record 14 of Set 21 | lalmohan
# Processing Record 15 of Set 21 | dawlatabad
# Processing Record 16 of Set 21 | ulverstone
# Processing Record 17 of Set 21 | san carlos de bariloche
# Processing Record 18 of Set 21 | hobyo
# Processing Record 19 of Set 21 | lagos
# Processing Record 20 of Set 21 | dapaong
# Processing Record 21 of Set 21 | ponta delgada
# Processing Record 22 of Set 21 | ostrovnoy
# Processing Record 23 of Set 21 | catamarca
# Processing Record 24 of Set 21 | port hawkesbury
# Processing Record 25 of Set 21 | ballina
# Processing Record 26 of Set 21 | carutapera
# Processing Record 27 of Set 21 | lincoln
# Processing Record 28 of Set 21 | whitehorse
# Processing Record 29 of Set 21 | novikovo
# Processing Record 30 of Set 21 | muli
# Processing Record 31 of Set 21 | hamilton
# Processing Record 32 of Set 21 | manaus
# Processing Record 33 of Set 21 | motygino
# Processing Record 34 of Set 21 | segezha
# Processing Record 35 of Set 21 | cleveland
# Processing Record 36 of Set 21 | bilibino
# Processing Record 37 of Set 21 | pringsewu
# Processing Record 38 of Set 21 | angostura
# Processing Record 39 of Set 21 | banepa
# Processing Record 40 of Set 21 | meulaboh
# Processing Record 41 of Set 21 | requena
# Processing Record 42 of Set 21 | trencin
# Processing Record 43 of Set 21 | tasbuget
# City not found. Skipping...
# Processing Record 44 of Set 21 | alexandria
# Processing Record 45 of Set 21 | ossora
# Processing Record 46 of Set 21 | rio pardo
# Processing Record 47 of Set 21 | kriel
# Processing Record 48 of Set 21 | sur
# Processing Record 49 of Set 21 | den helder
# Processing Record 50 of Set 21 | souillac
# Processing Record 1 of Set 22 | kemi
# Processing Record 2 of Set 22 | fortuna
# Processing Record 3 of Set 22 | quatre cocos
# Processing Record 4 of Set 22 | pangody
# Processing Record 5 of Set 22 | copacabana
# Processing Record 6 of Set 22 | fairview
# Processing Record 7 of Set 22 | reconquista
# Processing Record 8 of Set 22 | zhigalovo
# Processing Record 9 of Set 22 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 22 | caloundra
# Processing Record 11 of Set 22 | kindu
# Processing Record 12 of Set 22 | sambava
# Processing Record 13 of Set 22 | tevaitoa
# Processing Record 14 of Set 22 | flinders
# Processing Record 15 of Set 22 | fort nelson
# Processing Record 16 of Set 22 | caceres
# Processing Record 17 of Set 22 | katangli
# Processing Record 18 of Set 22 | alofi
# Processing Record 19 of Set 22 | morondava
# Processing Record 20 of Set 22 | dudinka
# Processing Record 21 of Set 22 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 22 | chabahar
# Processing Record 23 of Set 22 | boyuibe
# Processing Record 24 of Set 22 | saint-francois
# Processing Record 25 of Set 22 | ghanzi
# Processing Record 26 of Set 22 | shizunai
# Processing Record 27 of Set 22 | la plata
# Processing Record 28 of Set 22 | pinheiro machado
# Processing Record 29 of Set 22 | vasai
# Processing Record 30 of Set 22 | vinh
# Processing Record 31 of Set 22 | llanes
# Processing Record 32 of Set 22 | orange cove
# Processing Record 33 of Set 22 | ranong
# Processing Record 34 of Set 22 | roma
# Processing Record 35 of Set 22 | alcudia
# Processing Record 36 of Set 22 | belaya gora
# Processing Record 37 of Set 22 | orlik
# Processing Record 38 of Set 22 | tuatapere
# Processing Record 39 of Set 22 | limbang
# Processing Record 40 of Set 22 | hualmay
# Processing Record 41 of Set 22 | guiglo
# Processing Record 42 of Set 22 | guane
# Processing Record 43 of Set 22 | ritchie
# Processing Record 44 of Set 22 | najran
# Processing Record 45 of Set 22 | yulara
# Processing Record 46 of Set 22 | namibe
# Processing Record 47 of Set 22 | lokosovo
# Processing Record 48 of Set 22 | ust-kulom
# Processing Record 49 of Set 22 | jevnaker
# Processing Record 50 of Set 22 | alim
# Processing Record 1 of Set 23 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 23 | rawdon
# Processing Record 3 of Set 23 | banjar
# Processing Record 4 of Set 23 | monze
# Processing Record 5 of Set 23 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 23 | comodoro rivadavia
# Processing Record 7 of Set 23 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 23 | rawlins
# Processing Record 9 of Set 23 | am timan
# Processing Record 10 of Set 23 | aklavik
# Processing Record 11 of Set 23 | aquiraz
# Processing Record 12 of Set 23 | matehuala
# Processing Record 13 of Set 23 | saint-pierre
# Processing Record 14 of Set 23 | maceio
# Processing Record 15 of Set 23 | harpanahalli
# Processing Record 16 of Set 23 | lewiston
# Processing Record 17 of Set 23 | felidhoo
# City not found. Skipping...
# Processing Record 18 of Set 23 | ulladulla
# Processing Record 19 of Set 23 | camocim
# Processing Record 20 of Set 23 | trat
# Processing Record 21 of Set 23 | mangrol
# Processing Record 22 of Set 23 | yatou
# Processing Record 23 of Set 23 | vestmannaeyjar
# Processing Record 24 of Set 23 | sandane
# Processing Record 25 of Set 23 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 23 | matara
# Processing Record 27 of Set 23 | sechura
# Processing Record 28 of Set 23 | clarence town
# Processing Record 29 of Set 23 | sibu
# Processing Record 30 of Set 23 | rauma
# Processing Record 31 of Set 23 | benghazi
# Processing Record 32 of Set 23 | dharchula
# Processing Record 33 of Set 23 | nurota
# Processing Record 34 of Set 23 | houma
# Processing Record 35 of Set 23 | bardiyah
# Processing Record 36 of Set 23 | bazarnyye mataki
# Processing Record 37 of Set 23 | barkhan
# Processing Record 38 of Set 23 | rostaq
# City not found. Skipping...
# Processing Record 39 of Set 23 | evensk
# Processing Record 40 of Set 23 | port hedland
# Processing Record 41 of Set 23 | salalah
# Processing Record 42 of Set 23 | pontal do parana
# Processing Record 43 of Set 23 | grand gaube
# Processing Record 44 of Set 23 | guerrero negro
# Processing Record 45 of Set 23 | srandakan
# Processing Record 46 of Set 23 | nhulunbuy
# Processing Record 47 of Set 23 | port blair
# Processing Record 48 of Set 23 | coquimbo
# Processing Record 49 of Set 23 | rudsar
# Processing Record 50 of Set 23 | talakan
# Processing Record 1 of Set 24 | asau
# Processing Record 2 of Set 24 | kautokeino
# Processing Record 3 of Set 24 | burica
# City not found. Skipping...
# Processing Record 4 of Set 24 | kulhudhuffushi
# Processing Record 5 of Set 24 | werda
# Processing Record 6 of Set 24 | obluche
# City not found. Skipping...
# Processing Record 7 of Set 24 | sumbe
# Processing Record 8 of Set 24 | berlevag
# Processing Record 9 of Set 24 | puerto ayacucho
# Processing Record 10 of Set 24 | dryden
# Processing Record 11 of Set 24 | kiama
# Processing Record 12 of Set 24 | tanggu
# Processing Record 13 of Set 24 | rolim de moura
# City not found. Skipping...
# Processing Record 14 of Set 24 | mogadishu
# Processing Record 15 of Set 24 | itarema
# Processing Record 16 of Set 24 | bandarbeyla
# Processing Record 17 of Set 24 | emba
# Processing Record 18 of Set 24 | villa maria
# Processing Record 19 of Set 24 | barra
# Processing Record 20 of Set 24 | shingu
# Processing Record 21 of Set 24 | kesinga
# Processing Record 22 of Set 24 | saint-georges
# Processing Record 23 of Set 24 | zaozerne
# Processing Record 24 of Set 24 | kruisfontein
# Processing Record 25 of Set 24 | ryotsu
# Processing Record 26 of Set 24 | portland
# Processing Record 27 of Set 24 | boyolangu
# Processing Record 28 of Set 24 | mazara del vallo
# Processing Record 29 of Set 24 | viedma
# Processing Record 30 of Set 24 | wamba
# Processing Record 31 of Set 24 | moyale
# Processing Record 32 of Set 24 | gorin
# Processing Record 33 of Set 24 | kaka
# Processing Record 34 of Set 24 | san giovanni rotondo
# Processing Record 35 of Set 24 | caruray
# Processing Record 36 of Set 24 | stara moravica
# Processing Record 37 of Set 24 | yumen
# Processing Record 38 of Set 24 | palimbang
# Processing Record 39 of Set 24 | lakshettipet
# Processing Record 40 of Set 24 | mitsamiouli
# Processing Record 41 of Set 24 | ambon
# Processing Record 42 of Set 24 | topolovgrad
# Processing Record 43 of Set 24 | urambo
# Processing Record 44 of Set 24 | klaksvik
# Processing Record 45 of Set 24 | plettenberg bay
# Processing Record 46 of Set 24 | mayahi
# Processing Record 47 of Set 24 | sinop
# Processing Record 48 of Set 24 | praxedis guerrero
# Processing Record 49 of Set 24 | kununurra
# Processing Record 50 of Set 24 | baculin
# Processing Record 1 of Set 25 | kondinskoye
# Processing Record 2 of Set 25 | kipini
# Processing Record 3 of Set 25 | starokostyantyniv
# Processing Record 4 of Set 25 | lumeje
# Processing Record 5 of Set 25 | gravdal
# Processing Record 6 of Set 25 | pondicherry
# Processing Record 7 of Set 25 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 25 | ilebo
# Processing Record 9 of Set 25 | wenling
# Processing Record 10 of Set 25 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 25 | chimbote
# Processing Record 12 of Set 25 | dalbandin
# Processing Record 13 of Set 25 | puerto rondon
# Processing Record 14 of Set 25 | culebra
# Processing Record 15 of Set 25 | moroni
# Processing Record 16 of Set 25 | praia
# Processing Record 17 of Set 25 | polunochnoye
# Processing Record 18 of Set 25 | rodrigues alves
# Processing Record 19 of Set 25 | rakovnik
# Processing Record 20 of Set 25 | homer
# Processing Record 21 of Set 25 | moose factory
# Processing Record 22 of Set 25 | nortelandia
# Processing Record 23 of Set 25 | nome
# Processing Record 24 of Set 25 | vila velha
# Processing Record 25 of Set 25 | westport
# Processing Record 26 of Set 25 | weligama
# Processing Record 27 of Set 25 | arman
# Processing Record 28 of Set 25 | ust-kuyga
# Processing Record 29 of Set 25 | vao
# Processing Record 30 of Set 25 | sirumugai
# Processing Record 31 of Set 25 | thyboron
# Processing Record 32 of Set 25 | saint-joseph
# Processing Record 33 of Set 25 | elizabethtown
# Processing Record 34 of Set 25 | atasu
# Processing Record 35 of Set 25 | missoula
# Processing Record 36 of Set 25 | billings
# Processing Record 37 of Set 25 | ekhabi
# Processing Record 38 of Set 25 | chernyshevskiy
# Processing Record 39 of Set 25 | port shepstone
# Processing Record 40 of Set 25 | marzuq
# Processing Record 41 of Set 25 | marawi
# Processing Record 42 of Set 25 | baillif
# Processing Record 43 of Set 25 | kumluca
# Processing Record 44 of Set 25 | tabuk
# Processing Record 45 of Set 25 | rosarito
# Processing Record 46 of Set 25 | coihaique
# Processing Record 47 of Set 25 | vestmanna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth -33.9180   25.5701     57.09        76          20
# 1         Rikitea -23.1203 -134.9692     73.40        64         100
# 2        Kirakira -10.4544  161.9205     78.55        85          63
# 3           Vaini -21.2000 -175.2000     73.56        88          90
# 4          Inuvik  68.3499 -133.7218     34.56        97          90
# 5          Bethel  41.3712  -73.4140     77.49        63          40
# 6  Ribeira Grande  38.5167  -28.7000     75.60        78          20
# 7          Tiznit  29.5833   -9.5000     63.77        72         100
# 8      Pascagoula  30.3658  -88.5561     82.40        79          40
# 9   Valle Hermoso  25.6667  -97.8333     88.83        45          81
#
#    Wind Speed Country                 Date
# 0        6.91      ZA  2021-10-03 18:33:53
# 1       17.65      PF  2021-10-03 18:35:37
# 2        2.24      SB  2021-10-03 18:36:38
# 3        9.22      TO  2021-10-03 18:35:41
# 4       18.41      CA  2021-10-03 18:36:38
# 5        5.75      US  2021-10-03 18:36:39
# 6       11.50      PT  2021-10-03 18:36:21
# 7        4.72      MA  2021-10-03 18:36:39
# 8       10.36      US  2021-10-03 18:36:40
# 9        9.22      MX  2021-10-03 18:36:40

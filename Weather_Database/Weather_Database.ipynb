# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0089b060fc68e7a641e9237dab69fbc2

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0089b060fc68e7a641e9237dab69fbc2&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | mahebourg
# Processing Record 2 of Set 15 | vestmanna
# Processing Record 3 of Set 15 | ushuaia
# Processing Record 4 of Set 15 | bredasdorp
# Processing Record 5 of Set 15 | acajutla
# Processing Record 6 of Set 15 | sakakah
# Processing Record 7 of Set 15 | saint-philippe
# Processing Record 8 of Set 15 | natal
# Processing Record 9 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 15 | rikitea
# Processing Record 12 of Set 15 | kahului
# Processing Record 13 of Set 15 | seguin
# Processing Record 14 of Set 15 | hobart
# Processing Record 15 of Set 15 | barrow
# Processing Record 16 of Set 15 | upernavik
# Processing Record 17 of Set 15 | atuona
# Processing Record 18 of Set 15 | cape town
# Processing Record 19 of Set 15 | vaini
# Processing Record 20 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 15 | albany
# Processing Record 22 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 15 | tarata
# Processing Record 24 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 15 | berberati
# Processing Record 26 of Set 15 | bluff
# Processing Record 27 of Set 15 | omsukchan
# Processing Record 28 of Set 15 | kapaa
# Processing Record 29 of Set 15 | guayaramerin
# Processing Record 30 of Set 15 | chulym
# Processing Record 31 of Set 15 | mataura
# Processing Record 32 of Set 15 | saldanha
# Processing Record 33 of Set 15 | touros
# Processing Record 34 of Set 15 | pevek
# Processing Record 35 of Set 15 | hilo
# Processing Record 36 of Set 15 | hutchinson
# Processing Record 37 of Set 15 | tairua
# Processing Record 38 of Set 15 | gariaband
# Processing Record 39 of Set 15 | tabuk
# Processing Record 40 of Set 15 | jeremie
# Processing Record 41 of Set 15 | jamestown
# Processing Record 42 of Set 15 | cockburn town
# Processing Record 43 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 15 | qaanaaq
# Processing Record 45 of Set 15 | castro
# Processing Record 46 of Set 15 | zdunska wola
# Processing Record 47 of Set 15 | bethel
# Processing Record 48 of Set 15 | dikson
# Processing Record 49 of Set 15 | fengzhen
# Processing Record 50 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 16 | mehamn
# Processing Record 2 of Set 16 | ashtabula
# Processing Record 3 of Set 16 | avarua
# Processing Record 4 of Set 16 | provideniya
# Processing Record 5 of Set 16 | longyearbyen
# Processing Record 6 of Set 16 | puerto el triunfo
# Processing Record 7 of Set 16 | yar-sale
# Processing Record 8 of Set 16 | gambela
# Processing Record 9 of Set 16 | araouane
# Processing Record 10 of Set 16 | santa fe
# Processing Record 11 of Set 16 | yellowknife
# Processing Record 12 of Set 16 | ribeira grande
# Processing Record 13 of Set 16 | rio gallegos
# Processing Record 14 of Set 16 | amahai
# Processing Record 15 of Set 16 | honningsvag
# Processing Record 16 of Set 16 | manggar
# Processing Record 17 of Set 16 | esperance
# Processing Record 18 of Set 16 | east london
# Processing Record 19 of Set 16 | sydney
# Processing Record 20 of Set 16 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 21 of Set 16 | saint-louis
# Processing Record 22 of Set 16 | zarubino
# Processing Record 23 of Set 16 | pimentel
# Processing Record 24 of Set 16 | avera
# Processing Record 25 of Set 16 | carnarvon
# Processing Record 26 of Set 16 | port lincoln
# Processing Record 27 of Set 16 | nikolskoye
# Processing Record 28 of Set 16 | kaitangata
# Processing Record 29 of Set 16 | new norfolk
# Processing Record 30 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 16 | ulaangom
# Processing Record 32 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 16 | bambous virieux
# Processing Record 34 of Set 16 | cockburn harbour
# City not found. Skipping...
# Processing Record 35 of Set 16 | tapiramuta
# Processing Record 36 of Set 16 | sault sainte marie
# Processing Record 37 of Set 16 | coolum beach
# Processing Record 38 of Set 16 | freeport
# Processing Record 39 of Set 16 | san patricio
# Processing Record 40 of Set 16 | kodiak
# Processing Record 41 of Set 16 | kautokeino
# Processing Record 42 of Set 16 | port elizabeth
# Processing Record 43 of Set 16 | tuktoyaktuk
# Processing Record 44 of Set 16 | richards bay
# Processing Record 45 of Set 16 | aklavik
# Processing Record 46 of Set 16 | palmer
# Processing Record 47 of Set 16 | payakumbuh
# Processing Record 48 of Set 16 | zhangye
# Processing Record 49 of Set 16 | tessalit
# Processing Record 50 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 17 | kysyl-syr
# Processing Record 2 of Set 17 | bull savanna
# Processing Record 3 of Set 17 | tak
# Processing Record 4 of Set 17 | torbay
# Processing Record 5 of Set 17 | lipany
# Processing Record 6 of Set 17 | plover
# Processing Record 7 of Set 17 | talnakh
# Processing Record 8 of Set 17 | chapais
# Processing Record 9 of Set 17 | luderitz
# Processing Record 10 of Set 17 | nueva concepcion
# Processing Record 11 of Set 17 | pisco
# Processing Record 12 of Set 17 | ucluelet
# Processing Record 13 of Set 17 | reconquista
# Processing Record 14 of Set 17 | cidreira
# Processing Record 15 of Set 17 | kinablangan
# Processing Record 16 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 17 | wlodawa
# Processing Record 18 of Set 17 | dori
# Processing Record 19 of Set 17 | lufilufi
# Processing Record 20 of Set 17 | arraial do cabo
# Processing Record 21 of Set 17 | la mesa
# Processing Record 22 of Set 17 | xiongshi
# City not found. Skipping...
# Processing Record 23 of Set 17 | busselton
# Processing Record 24 of Set 17 | punta arenas
# Processing Record 25 of Set 17 | zhigansk
# Processing Record 26 of Set 17 | harper
# Processing Record 27 of Set 17 | acapulco
# Processing Record 28 of Set 17 | inyonga
# Processing Record 29 of Set 17 | marawi
# Processing Record 30 of Set 17 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 17 | rio grande
# Processing Record 32 of Set 17 | dakar
# Processing Record 33 of Set 17 | maragogi
# Processing Record 34 of Set 17 | college
# Processing Record 35 of Set 17 | ilulissat
# Processing Record 36 of Set 17 | butaritari
# Processing Record 37 of Set 17 | roald
# Processing Record 38 of Set 17 | faanui
# Processing Record 39 of Set 17 | tuatapere
# Processing Record 40 of Set 17 | san rafael
# Processing Record 41 of Set 17 | lebu
# Processing Record 42 of Set 17 | thompson
# Processing Record 43 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 17 | adrar
# Processing Record 45 of Set 17 | the valley
# Processing Record 46 of Set 17 | necochea
# Processing Record 47 of Set 17 | hermanus
# Processing Record 48 of Set 17 | vila velha
# Processing Record 49 of Set 17 | northam
# Processing Record 50 of Set 17 | puerto ayora
# Processing Record 1 of Set 18 | sesheke
# Processing Record 2 of Set 18 | najran
# Processing Record 3 of Set 18 | khatanga
# Processing Record 4 of Set 18 | naze
# Processing Record 5 of Set 18 | roma
# Processing Record 6 of Set 18 | asau
# Processing Record 7 of Set 18 | hofn
# Processing Record 8 of Set 18 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 9 of Set 18 | chokurdakh
# Processing Record 10 of Set 18 | vostok
# Processing Record 11 of Set 18 | narasannapeta
# Processing Record 12 of Set 18 | cherskiy
# Processing Record 13 of Set 18 | lagoa
# Processing Record 14 of Set 18 | caravelas
# Processing Record 15 of Set 18 | conde
# Processing Record 16 of Set 18 | vestmannaeyjar
# Processing Record 17 of Set 18 | alamos
# Processing Record 18 of Set 18 | lorengau
# Processing Record 19 of Set 18 | hot springs
# Processing Record 20 of Set 18 | port shepstone
# Processing Record 21 of Set 18 | mar del plata
# Processing Record 22 of Set 18 | leningradskiy
# Processing Record 23 of Set 18 | san quintin
# Processing Record 24 of Set 18 | zapolyarnyy
# Processing Record 25 of Set 18 | seoul
# Processing Record 26 of Set 18 | salalah
# Processing Record 27 of Set 18 | nouadhibou
# Processing Record 28 of Set 18 | taltal
# Processing Record 29 of Set 18 | reshetylivka
# Processing Record 30 of Set 18 | chokwe
# Processing Record 31 of Set 18 | ambilobe
# Processing Record 32 of Set 18 | saskylakh
# Processing Record 33 of Set 18 | kampong thum
# Processing Record 34 of Set 18 | clyde river
# Processing Record 35 of Set 18 | belmonte
# Processing Record 36 of Set 18 | bodden town
# Processing Record 37 of Set 18 | grindavik
# Processing Record 38 of Set 18 | xining
# Processing Record 39 of Set 18 | norman wells
# Processing Record 40 of Set 18 | saint-leu-la-foret
# Processing Record 41 of Set 18 | sitka
# Processing Record 42 of Set 18 | shenzhen
# Processing Record 43 of Set 18 | japura
# Processing Record 44 of Set 18 | xuddur
# Processing Record 45 of Set 18 | port alfred
# Processing Record 46 of Set 18 | nanortalik
# Processing Record 47 of Set 18 | rambha
# Processing Record 48 of Set 18 | manaure
# Processing Record 49 of Set 18 | hambantota
# Processing Record 50 of Set 18 | narsaq
# Processing Record 1 of Set 19 | turukhansk
# Processing Record 2 of Set 19 | istisu
# Processing Record 3 of Set 19 | kerki
# City not found. Skipping...
# Processing Record 4 of Set 19 | george
# Processing Record 5 of Set 19 | betsiamites
# Processing Record 6 of Set 19 | comodoro rivadavia
# Processing Record 7 of Set 19 | felipe carrillo puerto
# Processing Record 8 of Set 19 | fort nelson
# Processing Record 9 of Set 19 | lasem
# Processing Record 10 of Set 19 | wangkui
# Processing Record 11 of Set 19 | eyl
# Processing Record 12 of Set 19 | dingle
# Processing Record 13 of Set 19 | vanimo
# Processing Record 14 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 19 | kailua
# Processing Record 16 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 19 | vagur
# Processing Record 18 of Set 19 | chippewa falls
# Processing Record 19 of Set 19 | airai
# Processing Record 20 of Set 19 | san andres
# Processing Record 21 of Set 19 | gorey
# Processing Record 22 of Set 19 | saint anthony
# Processing Record 23 of Set 19 | moba
# Processing Record 24 of Set 19 | hukuntsi
# Processing Record 25 of Set 19 | shimoda
# Processing Record 26 of Set 19 | bengkulu
# Processing Record 27 of Set 19 | serpa
# Processing Record 28 of Set 19 | tasiilaq
# Processing Record 29 of Set 19 | kruisfontein
# Processing Record 30 of Set 19 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 19 | saint-joseph
# Processing Record 32 of Set 19 | kamloops
# Processing Record 33 of Set 19 | abu dhabi
# Processing Record 34 of Set 19 | bobonong
# City not found. Skipping...
# Processing Record 35 of Set 19 | ames
# Processing Record 36 of Set 19 | barra patuca
# Processing Record 37 of Set 19 | almaznyy
# Processing Record 38 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 19 | guerrero negro
# Processing Record 40 of Set 19 | innisfail
# Processing Record 41 of Set 19 | ponta do sol
# Processing Record 42 of Set 19 | souillac
# Processing Record 43 of Set 19 | isangel
# Processing Record 44 of Set 19 | zanjan
# Processing Record 45 of Set 19 | deep river
# Processing Record 46 of Set 19 | goderich
# Processing Record 47 of Set 19 | keelung
# Processing Record 48 of Set 19 | portland
# Processing Record 49 of Set 19 | te anau
# Processing Record 50 of Set 19 | pontianak
# Processing Record 1 of Set 20 | karratha
# Processing Record 2 of Set 20 | buchanan
# Processing Record 3 of Set 20 | melfi
# Processing Record 4 of Set 20 | sao gabriel da cachoeira
# Processing Record 5 of Set 20 | flin flon
# Processing Record 6 of Set 20 | kroya
# Processing Record 7 of Set 20 | constitucion
# Processing Record 8 of Set 20 | ornskoldsvik
# Processing Record 9 of Set 20 | kamiiso
# Processing Record 10 of Set 20 | preston
# Processing Record 11 of Set 20 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 20 | owando
# Processing Record 13 of Set 20 | sabha
# Processing Record 14 of Set 20 | tiksi
# Processing Record 15 of Set 20 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 20 | ossora
# Processing Record 17 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 20 | ancud
# Processing Record 19 of Set 20 | scottsbluff
# Processing Record 20 of Set 20 | kajaani
# Processing Record 21 of Set 20 | dzilam gonzalez
# Processing Record 22 of Set 20 | hithadhoo
# City not found. Skipping...
# Processing Record 23 of Set 20 | ondjiva
# Processing Record 24 of Set 20 | anadyr
# Processing Record 25 of Set 20 | simi
# Processing Record 26 of Set 20 | umea
# Processing Record 27 of Set 20 | severodvinsk
# Processing Record 28 of Set 20 | hayato
# City not found. Skipping...
# Processing Record 29 of Set 20 | oranjemund
# Processing Record 30 of Set 20 | aljezur
# Processing Record 31 of Set 20 | catalina foothills
# Processing Record 32 of Set 20 | oranjestad
# Processing Record 33 of Set 20 | sakaiminato
# Processing Record 34 of Set 20 | coihaique
# Processing Record 35 of Set 20 | faya
# Processing Record 36 of Set 20 | hasanabad
# Processing Record 37 of Set 20 | winnemucca
# Processing Record 38 of Set 20 | camocim
# Processing Record 39 of Set 20 | padang
# Processing Record 40 of Set 20 | dunedin
# Processing Record 41 of Set 20 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 20 | riachao das neves
# Processing Record 43 of Set 20 | klaksvik
# Processing Record 44 of Set 20 | ishigaki
# Processing Record 45 of Set 20 | chaozhou
# Processing Record 46 of Set 20 | namibe
# Processing Record 47 of Set 20 | hovd
# Processing Record 48 of Set 20 | san bartolome de tirajana
# Processing Record 49 of Set 20 | lata
# Processing Record 50 of Set 20 | waitati
# Processing Record 1 of Set 21 | kendari
# Processing Record 2 of Set 21 | egvekinot
# Processing Record 3 of Set 21 | morehead
# Processing Record 4 of Set 21 | korgen
# Processing Record 5 of Set 21 | laguna
# Processing Record 6 of Set 21 | cabo san lucas
# Processing Record 7 of Set 21 | digby
# Processing Record 8 of Set 21 | kedrovyy
# Processing Record 9 of Set 21 | salta
# Processing Record 10 of Set 21 | mount isa
# Processing Record 11 of Set 21 | raahe
# Processing Record 12 of Set 21 | hualmay
# Processing Record 13 of Set 21 | daxian
# City not found. Skipping...
# Processing Record 14 of Set 21 | san rafael del sur
# Processing Record 15 of Set 21 | cap malheureux
# Processing Record 16 of Set 21 | praia da vitoria
# Processing Record 17 of Set 21 | mana
# Processing Record 18 of Set 21 | korla
# Processing Record 19 of Set 21 | bud
# Processing Record 20 of Set 21 | saint-francois
# Processing Record 21 of Set 21 | tornio
# Processing Record 22 of Set 21 | zhongshu
# Processing Record 23 of Set 21 | lazaro cardenas
# Processing Record 24 of Set 21 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 21 | phan thiet
# Processing Record 26 of Set 21 | tilichiki
# Processing Record 27 of Set 21 | kuytun
# Processing Record 28 of Set 21 | saint-georges
# Processing Record 29 of Set 21 | balikpapan
# Processing Record 30 of Set 21 | det udom
# Processing Record 31 of Set 21 | tadine
# Processing Record 32 of Set 21 | pundaguitan
# Processing Record 33 of Set 21 | mount pleasant
# Processing Record 34 of Set 21 | plettenberg bay
# Processing Record 35 of Set 21 | port hardy
# Processing Record 36 of Set 21 | birin
# Processing Record 37 of Set 21 | temerloh
# Processing Record 38 of Set 21 | bubaque
# Processing Record 39 of Set 21 | severo-kurilsk
# Processing Record 40 of Set 21 | charagua
# Processing Record 41 of Set 21 | atar
# Processing Record 42 of Set 21 | kathmandu
# Processing Record 43 of Set 21 | bathsheba
# Processing Record 44 of Set 21 | port macquarie
# Processing Record 45 of Set 21 | bandarbeyla
# Processing Record 46 of Set 21 | hobyo
# Processing Record 47 of Set 21 | makakilo city
# Processing Record 48 of Set 21 | aktash
# Processing Record 49 of Set 21 | gijon
# Processing Record 50 of Set 21 | karakendzha
# City not found. Skipping...
# Processing Record 1 of Set 22 | saint george
# Processing Record 2 of Set 22 | carutapera
# Processing Record 3 of Set 22 | yenagoa
# Processing Record 4 of Set 22 | sinjar
# Processing Record 5 of Set 22 | portoferraio
# Processing Record 6 of Set 22 | pincher creek
# Processing Record 7 of Set 22 | teresopolis
# Processing Record 8 of Set 22 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 22 | deputatskiy
# Processing Record 10 of Set 22 | luganville
# Processing Record 11 of Set 22 | mandera
# Processing Record 12 of Set 22 | fairbanks
# Processing Record 13 of Set 22 | rawson
# Processing Record 14 of Set 22 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 22 | san pedro
# Processing Record 16 of Set 22 | zhuravka
# Processing Record 17 of Set 22 | ostrovnoy
# Processing Record 18 of Set 22 | georgetown
# Processing Record 19 of Set 22 | brunsbuttel
# Processing Record 20 of Set 22 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 22 | neijiang
# Processing Record 22 of Set 22 | yumen
# Processing Record 23 of Set 22 | hvammstangi
# City not found. Skipping...
# Processing Record 24 of Set 22 | panguna
# Processing Record 25 of Set 22 | ixtapa
# Processing Record 26 of Set 22 | inderborskiy
# City not found. Skipping...
# Processing Record 27 of Set 22 | dengzhou
# Processing Record 28 of Set 22 | seddon
# Processing Record 29 of Set 22 | pokhara
# Processing Record 30 of Set 22 | vardo
# Processing Record 31 of Set 22 | nokaneng
# Processing Record 32 of Set 22 | ayr
# Processing Record 33 of Set 22 | aratos
# Processing Record 34 of Set 22 | fernie
# Processing Record 35 of Set 22 | rudnya
# Processing Record 36 of Set 22 | fortuna
# Processing Record 37 of Set 22 | komsomolskiy
# Processing Record 38 of Set 22 | pemangkat
# Processing Record 39 of Set 22 | surt
# Processing Record 40 of Set 22 | russell
# Processing Record 41 of Set 22 | marshall
# Processing Record 42 of Set 22 | fort-shevchenko
# Processing Record 43 of Set 22 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 22 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 22 | chernyshevskiy
# Processing Record 46 of Set 22 | vallenar
# Processing Record 47 of Set 22 | srednekolymsk
# Processing Record 48 of Set 22 | fermoy
# Processing Record 49 of Set 22 | dondo
# Processing Record 50 of Set 22 | itaueira
# Processing Record 1 of Set 23 | aykhal
# Processing Record 2 of Set 23 | igarka
# Processing Record 3 of Set 23 | nemuro
# Processing Record 4 of Set 23 | inhambane
# Processing Record 5 of Set 23 | takoradi
# Processing Record 6 of Set 23 | magadan
# Processing Record 7 of Set 23 | cesme
# Processing Record 8 of Set 23 | katsuura
# Processing Record 9 of Set 23 | lompoc
# Processing Record 10 of Set 23 | morondava
# Processing Record 11 of Set 23 | yulara
# Processing Record 12 of Set 23 | tulun
# Processing Record 13 of Set 23 | umm lajj
# Processing Record 14 of Set 23 | sisimiut
# Processing Record 15 of Set 23 | tyrma
# Processing Record 16 of Set 23 | vila franca do campo
# Processing Record 17 of Set 23 | port hedland
# Processing Record 18 of Set 23 | ipilan
# Processing Record 19 of Set 23 | general cepeda
# Processing Record 20 of Set 23 | suluq
# Processing Record 21 of Set 23 | cartagena del chaira
# Processing Record 22 of Set 23 | jacareacanga
# Processing Record 23 of Set 23 | sechura
# Processing Record 24 of Set 23 | brae
# Processing Record 25 of Set 23 | mount gambier
# Processing Record 26 of Set 23 | lisala
# Processing Record 27 of Set 23 | garissa
# Processing Record 28 of Set 23 | leona vicario
# Processing Record 29 of Set 23 | broome
# Processing Record 30 of Set 23 | bapatla
# Processing Record 31 of Set 23 | tarakan
# Processing Record 32 of Set 23 | ayan
# Processing Record 33 of Set 23 | husavik
# Processing Record 34 of Set 23 | hay river
# Processing Record 35 of Set 23 | buta
# Processing Record 36 of Set 23 | marystown
# Processing Record 37 of Set 23 | vao
# Processing Record 38 of Set 23 | chara
# Processing Record 39 of Set 23 | keti bandar
# Processing Record 40 of Set 23 | san carlos de bariloche
# Processing Record 41 of Set 23 | le vauclin
# Processing Record 42 of Set 23 | sept-iles
# Processing Record 43 of Set 23 | eston
# Processing Record 44 of Set 23 | iqaluit
# Processing Record 45 of Set 23 | isparta
# Processing Record 46 of Set 23 | auki
# Processing Record 47 of Set 23 | victoria
# Processing Record 48 of Set 23 | luena
# Processing Record 49 of Set 23 | alugan
# Processing Record 50 of Set 23 | warrington
# Processing Record 1 of Set 24 | yerbogachen
# Processing Record 2 of Set 24 | sangar
# Processing Record 3 of Set 24 | ca mau
# Processing Record 4 of Set 24 | maniitsoq
# Processing Record 5 of Set 24 | hami
# Processing Record 6 of Set 24 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 24 | kathu
# Processing Record 8 of Set 24 | lensk
# Processing Record 9 of Set 24 | jumla
# Processing Record 10 of Set 24 | chimbote
# Processing Record 11 of Set 24 | betul
# Processing Record 12 of Set 24 | saint-pierre
# Processing Record 13 of Set 24 | sao filipe
# Processing Record 14 of Set 24 | nouakchott
# Processing Record 15 of Set 24 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 24 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 24 | dumai
# Processing Record 18 of Set 24 | vilhena
# Processing Record 19 of Set 24 | kavaratti
# Processing Record 20 of Set 24 | sexsmith
# Processing Record 21 of Set 24 | cayenne
# Processing Record 22 of Set 24 | porto novo
# Processing Record 23 of Set 24 | noumea
# Processing Record 24 of Set 24 | sebinkarahisar
# Processing Record 25 of Set 24 | timizart
# Processing Record 26 of Set 24 | ailigandi
# Processing Record 27 of Set 24 | nuuk
# Processing Record 28 of Set 24 | adeje
# Processing Record 29 of Set 24 | cazaje
# City not found. Skipping...
# Processing Record 30 of Set 24 | chipinge
# Processing Record 31 of Set 24 | jardim
# Processing Record 32 of Set 24 | poum
# Processing Record 33 of Set 24 | taitung
# Processing Record 34 of Set 24 | puerto del rosario
# Processing Record 35 of Set 24 | watsa
# Processing Record 36 of Set 24 | chute-aux-outardes
# Processing Record 37 of Set 24 | flinders
# Processing Record 38 of Set 24 | kemijarvi
# Processing Record 39 of Set 24 | tukrah
# Processing Record 40 of Set 24 | rocha
# Processing Record 41 of Set 24 | burnie
# Processing Record 42 of Set 24 | bonthe
# Processing Record 43 of Set 24 | arona
# Processing Record 44 of Set 24 | seymchan
# Processing Record 45 of Set 24 | iracoubo
# Processing Record 46 of Set 24 | krasnyy chikoy
# Processing Record 47 of Set 24 | niksar
# Processing Record 48 of Set 24 | quzhou
# Processing Record 49 of Set 24 | nara
# Processing Record 50 of Set 24 | atambua
# Processing Record 1 of Set 25 | edd
# Processing Record 2 of Set 25 | hanzhong
# Processing Record 3 of Set 25 | along
# Processing Record 4 of Set 25 | mahudha
# Processing Record 5 of Set 25 | vathi
# Processing Record 6 of Set 25 | nantucket
# Processing Record 7 of Set 25 | mokhsogollokh
# Processing Record 8 of Set 25 | puerto colombia
# Processing Record 9 of Set 25 | itarema
# Processing Record 10 of Set 25 | hervey bay
# Processing Record 11 of Set 25 | gamba
# Processing Record 12 of Set 25 | geraldton
# Processing Record 13 of Set 25 | lavrentiya
# Processing Record 14 of Set 25 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 25 | chuy
# Processing Record 16 of Set 25 | ballina
# Processing Record 17 of Set 25 | shanghai
# Processing Record 18 of Set 25 | qasigiannguit
# Processing Record 19 of Set 25 | nurota
# Processing Record 20 of Set 25 | tura
# Processing Record 21 of Set 25 | chulman
# Processing Record 22 of Set 25 | picota
# Processing Record 23 of Set 25 | boguchany
# Processing Record 24 of Set 25 | kuusamo
# Processing Record 25 of Set 25 | ascension
# Processing Record 26 of Set 25 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 25 | chinhoyi
# Processing Record 28 of Set 25 | lukulu
# Processing Record 29 of Set 25 | sinnamary
# Processing Record 30 of Set 25 | fairview
# Processing Record 31 of Set 25 | erie
# Processing Record 32 of Set 25 | mezen
# Processing Record 33 of Set 25 | khash
# Processing Record 34 of Set 25 | kalmar
# Processing Record 35 of Set 25 | yauya
# Processing Record 36 of Set 25 | miandrivazo
# Processing Record 37 of Set 25 | churapcha
# Processing Record 38 of Set 25 | henderson
# Processing Record 39 of Set 25 | birao
# Processing Record 40 of Set 25 | nevesinje
# Processing Record 41 of Set 25 | lakes entrance
# Processing Record 42 of Set 25 | berlevag
# Processing Record 43 of Set 25 | inuvik
# Processing Record 44 of Set 25 | tabou
# Processing Record 45 of Set 25 | massakory
# Processing Record 46 of Set 25 | yunjinghong
# City not found. Skipping...
# Processing Record 47 of Set 25 | praia
# Processing Record 48 of Set 25 | paredon
# Processing Record 49 of Set 25 | joetsu
# Processing Record 50 of Set 25 | koslan
# Processing Record 1 of Set 26 | talaya
# Processing Record 2 of Set 26 | kermanshah
# Processing Record 3 of Set 26 | kayerkan
# Processing Record 4 of Set 26 | kindu
# Processing Record 5 of Set 26 | sioux lookout
# Processing Record 6 of Set 26 | hamilton
# Processing Record 7 of Set 26 | jutai
# Processing Record 8 of Set 26 | roebourne
# Processing Record 9 of Set 26 | rosetta
# Processing Record 10 of Set 26 | orange cove
# Processing Record 11 of Set 26 | fare
# Processing Record 12 of Set 26 | hereford
# Processing Record 13 of Set 26 | kirakira
# Processing Record 14 of Set 26 | moa
# Processing Record 15 of Set 26 | vila
# Processing Record 16 of Set 26 | axim
# Processing Record 17 of Set 26 | boaco
# Processing Record 18 of Set 26 | nazilli
# Processing Record 19 of Set 26 | bundaberg
# Processing Record 20 of Set 26 | taganak
# Processing Record 21 of Set 26 | nalut
# Processing Record 22 of Set 26 | xacmaz
# Processing Record 23 of Set 26 | ziniare
# Processing Record 24 of Set 26 | bathurst
# Processing Record 25 of Set 26 | gravdal
# Processing Record 26 of Set 26 | beringovskiy
# Processing Record 27 of Set 26 | iralaya
# Processing Record 28 of Set 26 | mantua
# Processing Record 29 of Set 26 | laela
# Processing Record 30 of Set 26 | bissau
# Processing Record 31 of Set 26 | mwanza
# Processing Record 32 of Set 26 | belyy yar
# Processing Record 33 of Set 26 | colares
# Processing Record 34 of Set 26 | bestobe
# Processing Record 35 of Set 26 | westport
# Processing Record 36 of Set 26 | tual
# Processing Record 37 of Set 26 | lebork
# Processing Record 38 of Set 26 | amapa
# Processing Record 39 of Set 26 | pacific grove
# Processing Record 40 of Set 26 | ciudad valles
# Processing Record 41 of Set 26 | bluefields
# Processing Record 42 of Set 26 | markova
# Processing Record 43 of Set 26 | borba
# Processing Record 44 of Set 26 | meulaboh
# Processing Record 45 of Set 26 | blonduos
# City not found. Skipping...
# Processing Record 46 of Set 26 | pasighat
# Processing Record 47 of Set 26 | talcahuano
# Processing Record 48 of Set 26 | karaman
# Processing Record 49 of Set 26 | shaoguan
# Processing Record 50 of Set 26 | kupang
# Processing Record 1 of Set 27 | valparaiso
# Processing Record 2 of Set 27 | bonavista
# Processing Record 3 of Set 27 | novokruchininskiy
# Processing Record 4 of Set 27 | kavieng
# Processing Record 5 of Set 27 | simao
# Processing Record 6 of Set 27 | ust-kut
# Processing Record 7 of Set 27 | bam
# Processing Record 8 of Set 27 | nikolsk
# Processing Record 9 of Set 27 | yeppoon
# Processing Record 10 of Set 27 | formosa do rio preto
# Processing Record 11 of Set 27 | tazovskiy
# Processing Record 12 of Set 27 | adre
# Processing Record 13 of Set 27 | lyaskelya
# Processing Record 14 of Set 27 | shelbyville
# Processing Record 15 of Set 27 | mahenge
# Processing Record 16 of Set 27 | dwarka
# Processing Record 17 of Set 27 | tubuala
# Processing Record 18 of Set 27 | alvaraes
# Processing Record 19 of Set 27 | townsville
# Processing Record 20 of Set 27 | kununurra
# Processing Record 21 of Set 27 | taga
# Processing Record 22 of Set 27 | dipkarpaz
# City not found. Skipping...
# Processing Record 23 of Set 27 | tawau
# Processing Record 24 of Set 27 | presidencia roque saenz pena
# Processing Record 25 of Set 27 | dudinka
# Processing Record 26 of Set 27 | codrington
# Processing Record 27 of Set 27 | san jeronimo
# Processing Record 28 of Set 27 | jiuquan
# Processing Record 29 of Set 27 | batagay-alyta
# Processing Record 30 of Set 27 | safranbolu
# Processing Record 31 of Set 27 | kulhudhuffushi
# Processing Record 32 of Set 27 | safaga
# Processing Record 33 of Set 27 | khuzdar
# Processing Record 34 of Set 27 | miri
# Processing Record 35 of Set 27 | tessaoua
# Processing Record 36 of Set 27 | westerland
# Processing Record 37 of Set 27 | manbij
# Processing Record 38 of Set 27 | petrivka
# Processing Record 39 of Set 27 | disna
# Processing Record 40 of Set 27 | greencastle
# Processing Record 41 of Set 27 | greaca
# Processing Record 42 of Set 27 | svetlaya
# Processing Record 43 of Set 27 | jimenez
# Processing Record 44 of Set 27 | sorland
# Processing Record 45 of Set 27 | scarborough
# Processing Record 46 of Set 27 | esna
# Processing Record 47 of Set 27 | kachikau
# City not found. Skipping...
# Processing Record 48 of Set 27 | taburi
# City not found. Skipping...
# Processing Record 49 of Set 27 | san cristobal
# Processing Record 50 of Set 27 | muroto
# Processing Record 1 of Set 28 | uri
# Processing Record 2 of Set 28 | moron
# Processing Record 3 of Set 28 | kouroussa
# Processing Record 4 of Set 28 | trapani
# Processing Record 5 of Set 28 | pangnirtung
# Processing Record 6 of Set 28 | waingapu
# Processing Record 7 of Set 28 | tome
# Processing Record 8 of Set 28 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 28 | samarskoye
# Processing Record 10 of Set 28 | stromness
# Processing Record 11 of Set 28 | koster
# Processing Record 12 of Set 28 | maiduguri
# Processing Record 13 of Set 28 | sohag
# Processing Record 14 of Set 28 | mayo
# Processing Record 15 of Set 28 | bunia
# Processing Record 16 of Set 28 | wamba
# Processing Record 17 of Set 28 | terrace
# Processing Record 18 of Set 28 | staraya russa
# Processing Record 19 of Set 28 | wulanhaote
# City not found. Skipping...
# Processing Record 20 of Set 28 | am timan
# Processing Record 21 of Set 28 | liverpool
# Processing Record 22 of Set 28 | ishim
# Processing Record 23 of Set 28 | grand gaube
# Processing Record 24 of Set 28 | iskateley
# Processing Record 25 of Set 28 | penzance
# Processing Record 26 of Set 28 | itoman
# Processing Record 27 of Set 28 | loei
# Processing Record 28 of Set 28 | sarakhs
# Processing Record 29 of Set 28 | adela
# Processing Record 30 of Set 28 | lighthouse point
# Processing Record 31 of Set 28 | itaituba
# Processing Record 32 of Set 28 | cortez
# Processing Record 33 of Set 28 | guilin
# Processing Record 34 of Set 28 | beloha
# Processing Record 35 of Set 28 | predivinsk
# Processing Record 36 of Set 28 | muisne
# Processing Record 37 of Set 28 | huilong
# Processing Record 38 of Set 28 | fukue
# Processing Record 39 of Set 28 | muravlenko
# Processing Record 40 of Set 28 | oinoussai
# City not found. Skipping...
# Processing Record 41 of Set 28 | xiongzhou
# Processing Record 42 of Set 28 | karaton
# Processing Record 43 of Set 28 | dhidhdhoo
# Processing Record 44 of Set 28 | acari
# Processing Record 45 of Set 28 | poya
# Processing Record 46 of Set 28 | nevelsk
# Processing Record 47 of Set 28 | tobermory
# Processing Record 48 of Set 28 | voyvozh
# Processing Record 49 of Set 28 | morros
# Processing Record 50 of Set 28 | zhangjiakou
# Processing Record 1 of Set 29 | waspan
# Processing Record 2 of Set 29 | nome
# Processing Record 3 of Set 29 | ambagarh chauki
# Processing Record 4 of Set 29 | bom jesus
# Processing Record 5 of Set 29 | uni
# Processing Record 6 of Set 29 | ous
# Processing Record 7 of Set 29 | keroka
# Processing Record 8 of Set 29 | mecca
# Processing Record 9 of Set 29 | baculin
# Processing Record 10 of Set 29 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 29 | matagami
# Processing Record 12 of Set 29 | sol-iletsk
# Processing Record 13 of Set 29 | sahbuz
# Processing Record 14 of Set 29 | healdsburg
# Processing Record 15 of Set 29 | rajgarh
# Processing Record 16 of Set 29 | huarmey
# Processing Record 17 of Set 29 | byron bay
# Processing Record 18 of Set 29 | tiznit
# Processing Record 19 of Set 29 | tver
# Processing Record 20 of Set 29 | sola
# Processing Record 21 of Set 29 | quatre cocos
# Processing Record 22 of Set 29 | okha
# Processing Record 23 of Set 29 | zhoucheng
# Processing Record 24 of Set 29 | paracuru
# Processing Record 25 of Set 29 | port augusta
# Processing Record 26 of Set 29 | mawlaik
# Processing Record 27 of Set 29 | bereda
# Processing Record 28 of Set 29 | nador
# Processing Record 29 of Set 29 | wilmington
# Processing Record 30 of Set 29 | nizhniy mamon
# Processing Record 31 of Set 29 | kropotkin
# Processing Record 32 of Set 29 | abu jubayhah
# City not found. Skipping...
# Processing Record 33 of Set 29 | kungurtug
# Processing Record 34 of Set 29 | dakoro
# Processing Record 35 of Set 29 | neuquen
# Processing Record 36 of Set 29 | bealanana
# Processing Record 37 of Set 29 | ternate
# Processing Record 38 of Set 29 | sigli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mahebourg -20.4081   57.7000     73.26        88          75
# 1       Vestmanna  62.1564   -7.1664     45.52       100          90
# 2         Ushuaia -54.8000  -68.3000     46.06        76          75
# 3      Bredasdorp -34.5322   20.0403     50.29        87          13
# 4        Acajutla  13.5928  -89.8275     85.19        69          33
# 5         Sakakah  29.9697   40.2064     83.77        26           0
# 6  Saint-Philippe -21.3585   55.7679     72.99        82          44
# 7           Natal  -5.7950  -35.2094     84.85        54           0
# 8         Rikitea -23.1203 -134.9692     73.40        64         100
# 9         Kahului  20.8947 -156.4700     84.22        73          20
#
#    Wind Speed Country                 Date
# 0       11.50      MU  2021-10-03 19:25:27
# 1       44.87      FO  2021-10-03 19:25:27
# 2       27.63      AR  2021-10-03 19:21:59
# 3        3.44      ZA  2021-10-03 19:25:28
# 4        5.55      SV  2021-10-03 19:25:28
# 5       12.19      SA  2021-10-03 19:25:29
# 6       14.58      RE  2021-10-03 19:25:29
# 7       19.57      BR  2021-10-03 19:25:29
# 8       17.65      PF  2021-10-03 19:22:31
# 9       21.85      US  2021-10-03 19:25:30

# %%
pd.options.display.float_format = "{:.2f}".format
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Mahebourg -20.41   57.70     73.26        88          75       11.50
# 1       Vestmanna  62.16   -7.17     45.52       100          90       44.87
# 2         Ushuaia -54.80  -68.30     46.06        76          75       27.63
# 3      Bredasdorp -34.53   20.04     50.29        87          13        3.44
# 4        Acajutla  13.59  -89.83     85.19        69          33        5.55
# 5         Sakakah  29.97   40.21     83.77        26           0       12.19
# 6  Saint-Philippe -21.36   55.77     72.99        82          44       14.58
# 7           Natal  -5.79  -35.21     84.85        54           0       19.57
# 8         Rikitea -23.12 -134.97     73.40        64         100       17.65
# 9         Kahului  20.89 -156.47     84.22        73          20       21.85
#
#   Country                 Date
# 0      MU  2021-10-03 19:25:27
# 1      FO  2021-10-03 19:25:27
# 2      AR  2021-10-03 19:21:59
# 3      ZA  2021-10-03 19:25:28
# 4      SV  2021-10-03 19:25:28
# 5      SA  2021-10-03 19:25:29
# 6      RE  2021-10-03 19:25:29
# 7      BR  2021-10-03 19:25:29
# 8      PF  2021-10-03 19:22:31
# 9      US  2021-10-03 19:25:30

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

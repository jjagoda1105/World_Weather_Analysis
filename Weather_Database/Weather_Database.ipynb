# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0089b060fc68e7a641e9237dab69fbc2

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0089b060fc68e7a641e9237dab69fbc2&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_title = city_weather["name"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list
        city_data.append({"City": city_title,
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
        
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saldanha
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | estelle
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | geraldton
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | lake charles
# Processing Record 12 of Set 1 | esperance
# Processing Record 13 of Set 1 | aden
# Processing Record 14 of Set 1 | gat
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | beringovskiy
# Processing Record 19 of Set 1 | beirut
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | cam pha
# City not found. Skipping...
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | marquette
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | cabedelo
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | wattegama
# Processing Record 34 of Set 1 | half moon bay
# Processing Record 35 of Set 1 | araouane
# Processing Record 36 of Set 1 | fortuna
# Processing Record 37 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 38 of Set 1 | guerrero negro
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | castro
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | codrington
# Processing Record 46 of Set 1 | gizo
# Processing Record 47 of Set 1 | beloha
# Processing Record 48 of Set 1 | zhuhai
# Processing Record 49 of Set 1 | vitim
# Processing Record 50 of Set 1 | puerto el triunfo
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | usinsk
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | miracema do tocantins
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | asau
# Processing Record 7 of Set 2 | vaitape
# Processing Record 8 of Set 2 | alakurtti
# Processing Record 9 of Set 2 | san vicente
# Processing Record 10 of Set 2 | tazovskiy
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | malanje
# Processing Record 13 of Set 2 | monrovia
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | airai
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | cuenca
# Processing Record 18 of Set 2 | lima
# Processing Record 19 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | lynchburg
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | saint anthony
# Processing Record 23 of Set 2 | tura
# Processing Record 24 of Set 2 | comodoro rivadavia
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | pundaguitan
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | homer
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | san pawl il-bahar
# Processing Record 32 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 2 | trinidad
# Processing Record 34 of Set 2 | raton
# Processing Record 35 of Set 2 | ahipara
# Processing Record 36 of Set 2 | sangerhausen
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | nazira
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | gamba
# Processing Record 42 of Set 2 | ghanzi
# Processing Record 43 of Set 2 | sofiysk
# City not found. Skipping...
# Processing Record 44 of Set 2 | salym
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | ostrovnoy
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | palana
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | nome
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | carbondale
# Processing Record 4 of Set 3 | gasa
# Processing Record 5 of Set 3 | tuatapere
# Processing Record 6 of Set 3 | severo-kurilsk
# Processing Record 7 of Set 3 | algiers
# Processing Record 8 of Set 3 | pijijiapan
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | luderitz
# Processing Record 11 of Set 3 | buala
# Processing Record 12 of Set 3 | taoudenni
# Processing Record 13 of Set 3 | havre
# Processing Record 14 of Set 3 | kjollefjord
# Processing Record 15 of Set 3 | kyra
# Processing Record 16 of Set 3 | mataura
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | vardo
# Processing Record 19 of Set 3 | nizhniy kuranakh
# Processing Record 20 of Set 3 | marihatag
# Processing Record 21 of Set 3 | jumla
# Processing Record 22 of Set 3 | irbil
# Processing Record 23 of Set 3 | bayonet point
# Processing Record 24 of Set 3 | oporapa
# Processing Record 25 of Set 3 | hemnesberget
# Processing Record 26 of Set 3 | marsabit
# Processing Record 27 of Set 3 | saint-louis
# Processing Record 28 of Set 3 | srednekolymsk
# Processing Record 29 of Set 3 | coihaique
# Processing Record 30 of Set 3 | gorontalo
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | katsuura
# Processing Record 33 of Set 3 | lewistown
# Processing Record 34 of Set 3 | waitati
# Processing Record 35 of Set 3 | pangnirtung
# Processing Record 36 of Set 3 | isangel
# Processing Record 37 of Set 3 | beira
# Processing Record 38 of Set 3 | tucurui
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | haines junction
# Processing Record 41 of Set 3 | bandarbeyla
# Processing Record 42 of Set 3 | senneterre
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | puerto escondido
# Processing Record 45 of Set 3 | hengshui
# Processing Record 46 of Set 3 | meulaboh
# Processing Record 47 of Set 3 | waldoboro
# Processing Record 48 of Set 3 | anantapur
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | ous
# Processing Record 2 of Set 4 | bijie
# Processing Record 3 of Set 4 | te anau
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | itarema
# Processing Record 6 of Set 4 | tofield
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | kayerkan
# Processing Record 11 of Set 4 | vung tau
# Processing Record 12 of Set 4 | voh
# Processing Record 13 of Set 4 | kampot
# Processing Record 14 of Set 4 | maningrida
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | hokitika
# Processing Record 17 of Set 4 | sainte-suzanne
# Processing Record 18 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 4 | chitral
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | encheng
# Processing Record 22 of Set 4 | codajas
# Processing Record 23 of Set 4 | sobradinho
# Processing Record 24 of Set 4 | severodvinsk
# Processing Record 25 of Set 4 | klaksvik
# Processing Record 26 of Set 4 | ouango
# Processing Record 27 of Set 4 | sambava
# Processing Record 28 of Set 4 | kidal
# Processing Record 29 of Set 4 | port hardy
# Processing Record 30 of Set 4 | faanui
# Processing Record 31 of Set 4 | norman wells
# Processing Record 32 of Set 4 | vangaindrano
# Processing Record 33 of Set 4 | bowen
# Processing Record 34 of Set 4 | sarangani
# Processing Record 35 of Set 4 | dubai
# Processing Record 36 of Set 4 | tekeli
# Processing Record 37 of Set 4 | mildura
# Processing Record 38 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 4 | kathmandu
# Processing Record 40 of Set 4 | pevek
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | bonavista
# Processing Record 43 of Set 4 | vestmannaeyjar
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | plouzane
# Processing Record 46 of Set 4 | narsaq
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | camacha
# Processing Record 49 of Set 4 | lander
# Processing Record 50 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 5 | onega
# Processing Record 2 of Set 5 | ojinaga
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | hobyo
# Processing Record 5 of Set 5 | buraydah
# Processing Record 6 of Set 5 | butaritari
# Processing Record 7 of Set 5 | broken hill
# Processing Record 8 of Set 5 | bridlington
# Processing Record 9 of Set 5 | kibala
# Processing Record 10 of Set 5 | saskylakh
# Processing Record 11 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 5 | nehe
# Processing Record 13 of Set 5 | saryozek
# Processing Record 14 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 15 of Set 5 | port lincoln
# Processing Record 16 of Set 5 | orlik
# Processing Record 17 of Set 5 | anadyr
# Processing Record 18 of Set 5 | port elizabeth
# Processing Record 19 of Set 5 | lavumisa
# Processing Record 20 of Set 5 | ntcheu
# Processing Record 21 of Set 5 | skjervoy
# Processing Record 22 of Set 5 | vysokogornyy
# Processing Record 23 of Set 5 | kalmar
# Processing Record 24 of Set 5 | jakar
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | gillette
# Processing Record 27 of Set 5 | tezu
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 5 | san francisco
# Processing Record 31 of Set 5 | fairbanks
# Processing Record 32 of Set 5 | maddur
# Processing Record 33 of Set 5 | tabuk
# Processing Record 34 of Set 5 | cayenne
# Processing Record 35 of Set 5 | ust-kuyga
# Processing Record 36 of Set 5 | sisimiut
# Processing Record 37 of Set 5 | grand island
# Processing Record 38 of Set 5 | masindi
# Processing Record 39 of Set 5 | breves
# Processing Record 40 of Set 5 | pathein
# Processing Record 41 of Set 5 | chuy
# Processing Record 42 of Set 5 | santa maria
# Processing Record 43 of Set 5 | sorong
# Processing Record 44 of Set 5 | umm kaddadah
# Processing Record 45 of Set 5 | hasaki
# Processing Record 46 of Set 5 | chokurdakh
# Processing Record 47 of Set 5 | ledyard
# Processing Record 48 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 5 | inuvik
# Processing Record 50 of Set 5 | ruteng
# Processing Record 1 of Set 6 | kodinar
# Processing Record 2 of Set 6 | rong kwang
# Processing Record 3 of Set 6 | nyurba
# Processing Record 4 of Set 6 | dingle
# Processing Record 5 of Set 6 | eenhana
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | trairi
# Processing Record 8 of Set 6 | zlobin
# Processing Record 9 of Set 6 | hami
# Processing Record 10 of Set 6 | acapulco
# Processing Record 11 of Set 6 | nara
# Processing Record 12 of Set 6 | havoysund
# Processing Record 13 of Set 6 | hambantota
# Processing Record 14 of Set 6 | touros
# Processing Record 15 of Set 6 | bathsheba
# Processing Record 16 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 6 | pointe-noire
# Processing Record 18 of Set 6 | vao
# Processing Record 19 of Set 6 | piracanjuba
# Processing Record 20 of Set 6 | feni
# Processing Record 21 of Set 6 | kalmunai
# Processing Record 22 of Set 6 | cherskiy
# Processing Record 23 of Set 6 | san ramon
# Processing Record 24 of Set 6 | lufilufi
# Processing Record 25 of Set 6 | ola
# Processing Record 26 of Set 6 | zamania
# Processing Record 27 of Set 6 | todos santos
# Processing Record 28 of Set 6 | agua branca
# Processing Record 29 of Set 6 | kesinga
# Processing Record 30 of Set 6 | sao filipe
# Processing Record 31 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 6 | magburaka
# Processing Record 33 of Set 6 | tambopata
# Processing Record 34 of Set 6 | shitanjing
# Processing Record 35 of Set 6 | achiotal
# City not found. Skipping...
# Processing Record 36 of Set 6 | oriximina
# Processing Record 37 of Set 6 | dwarka
# Processing Record 38 of Set 6 | saint-leu
# Processing Record 39 of Set 6 | lethem
# Processing Record 40 of Set 6 | kesennuma
# City not found. Skipping...
# Processing Record 41 of Set 6 | nador
# Processing Record 42 of Set 6 | manching
# Processing Record 43 of Set 6 | hamilton
# Processing Record 44 of Set 6 | snyder
# Processing Record 45 of Set 6 | male
# Processing Record 46 of Set 6 | pasni
# Processing Record 47 of Set 6 | teya
# Processing Record 48 of Set 6 | mount darwin
# Processing Record 49 of Set 6 | portland
# Processing Record 50 of Set 6 | kashan
# Processing Record 1 of Set 7 | mareeba
# Processing Record 2 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 3 of Set 7 | chokwe
# Processing Record 4 of Set 7 | rio grande
# Processing Record 5 of Set 7 | arman
# Processing Record 6 of Set 7 | adrar
# Processing Record 7 of Set 7 | tiksi
# Processing Record 8 of Set 7 | baraki barak
# Processing Record 9 of Set 7 | solwezi
# Processing Record 10 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 7 | cacule
# Processing Record 12 of Set 7 | egvekinot
# Processing Record 13 of Set 7 | elat
# Processing Record 14 of Set 7 | makakilo city
# Processing Record 15 of Set 7 | birin
# Processing Record 16 of Set 7 | pochutla
# Processing Record 17 of Set 7 | chalons-en-champagne
# Processing Record 18 of Set 7 | uyuni
# Processing Record 19 of Set 7 | wanaka
# Processing Record 20 of Set 7 | juneau
# Processing Record 21 of Set 7 | saint-francois
# Processing Record 22 of Set 7 | victor harbor
# Processing Record 23 of Set 7 | aklavik
# Processing Record 24 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | netanya
# Processing Record 27 of Set 7 | lalomanu
# City not found. Skipping...
# Processing Record 28 of Set 7 | provideniya
# Processing Record 29 of Set 7 | cabo san lucas
# Processing Record 30 of Set 7 | san quintin
# Processing Record 31 of Set 7 | hay river
# Processing Record 32 of Set 7 | dikson
# Processing Record 33 of Set 7 | novopokrovka
# Processing Record 34 of Set 7 | ribas do rio pardo
# Processing Record 35 of Set 7 | poum
# Processing Record 36 of Set 7 | berdigestyakh
# Processing Record 37 of Set 7 | huarmey
# Processing Record 38 of Set 7 | miraflores
# Processing Record 39 of Set 7 | champerico
# Processing Record 40 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 41 of Set 7 | awjilah
# Processing Record 42 of Set 7 | lavrentiya
# Processing Record 43 of Set 7 | gilgit
# Processing Record 44 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 7 | bestobe
# Processing Record 46 of Set 7 | payo
# Processing Record 47 of Set 7 | jurbarkas
# Processing Record 48 of Set 7 | kindersley
# Processing Record 49 of Set 7 | ambovombe
# Processing Record 50 of Set 7 | paragominas
# Processing Record 1 of Set 8 | aswan
# Processing Record 2 of Set 8 | sovetskiy
# Processing Record 3 of Set 8 | antibes
# Processing Record 4 of Set 8 | west lafayette
# Processing Record 5 of Set 8 | saint-joseph
# Processing Record 6 of Set 8 | souillac
# Processing Record 7 of Set 8 | lagoa
# Processing Record 8 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 9 of Set 8 | kindu
# Processing Record 10 of Set 8 | bealanana
# Processing Record 11 of Set 8 | lepe
# Processing Record 12 of Set 8 | grenfell
# Processing Record 13 of Set 8 | cangzhou
# Processing Record 14 of Set 8 | les cayes
# Processing Record 15 of Set 8 | singapore
# Processing Record 16 of Set 8 | uinskoye
# Processing Record 17 of Set 8 | burnie
# Processing Record 18 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 8 | aberdeen
# Processing Record 20 of Set 8 | santa marta
# Processing Record 21 of Set 8 | pinega
# Processing Record 22 of Set 8 | mercedes
# Processing Record 23 of Set 8 | kloulklubed
# Processing Record 24 of Set 8 | lagos
# Processing Record 25 of Set 8 | annonay
# Processing Record 26 of Set 8 | hede
# Processing Record 27 of Set 8 | jarinu
# Processing Record 28 of Set 8 | gazli
# Processing Record 29 of Set 8 | arraial do cabo
# Processing Record 30 of Set 8 | nagato
# Processing Record 31 of Set 8 | luangwa
# Processing Record 32 of Set 8 | quatre cocos
# Processing Record 33 of Set 8 | clarence town
# Processing Record 34 of Set 8 | shebunino
# Processing Record 35 of Set 8 | torbay
# Processing Record 36 of Set 8 | meadow lake
# Processing Record 37 of Set 8 | ternate
# Processing Record 38 of Set 8 | xucheng
# Processing Record 39 of Set 8 | pieve di soligo
# Processing Record 40 of Set 8 | aguas formosas
# Processing Record 41 of Set 8 | dalnegorsk
# Processing Record 42 of Set 8 | sitka
# Processing Record 43 of Set 8 | changtu
# Processing Record 44 of Set 8 | deputatskiy
# Processing Record 45 of Set 8 | totskoye
# Processing Record 46 of Set 8 | maymyo
# Processing Record 47 of Set 8 | iqaluit
# Processing Record 48 of Set 8 | hofn
# Processing Record 49 of Set 8 | san rafael
# Processing Record 50 of Set 8 | davila
# Processing Record 1 of Set 9 | mehamn
# Processing Record 2 of Set 9 | poya
# Processing Record 3 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 9 | georgetown
# Processing Record 5 of Set 9 | ponta delgada
# Processing Record 6 of Set 9 | andros town
# Processing Record 7 of Set 9 | eureka
# Processing Record 8 of Set 9 | charlottetown
# Processing Record 9 of Set 9 | zhuanghe
# Processing Record 10 of Set 9 | ouesso
# Processing Record 11 of Set 9 | nata
# Processing Record 12 of Set 9 | college
# Processing Record 13 of Set 9 | tanabe
# Processing Record 14 of Set 9 | salta
# Processing Record 15 of Set 9 | vincennes
# Processing Record 16 of Set 9 | omboue
# Processing Record 17 of Set 9 | berlevag
# Processing Record 18 of Set 9 | roma
# Processing Record 19 of Set 9 | maxixe
# Processing Record 20 of Set 9 | saint albans
# Processing Record 21 of Set 9 | lorengau
# Processing Record 22 of Set 9 | wukari
# Processing Record 23 of Set 9 | matamoros
# Processing Record 24 of Set 9 | san cristobal
# Processing Record 25 of Set 9 | dois irmaos
# Processing Record 26 of Set 9 | naberera
# Processing Record 27 of Set 9 | zhezkazgan
# Processing Record 28 of Set 9 | sur
# Processing Record 29 of Set 9 | talara
# Processing Record 30 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 9 | muravlenko
# Processing Record 32 of Set 9 | bandundu
# Processing Record 33 of Set 9 | west bay
# Processing Record 34 of Set 9 | morondava
# Processing Record 35 of Set 9 | oistins
# Processing Record 36 of Set 9 | mananjary
# Processing Record 37 of Set 9 | okhotsk
# Processing Record 38 of Set 9 | ketchikan
# Processing Record 39 of Set 9 | samarinda
# Processing Record 40 of Set 9 | ye
# City not found. Skipping...
# Processing Record 41 of Set 9 | lebu
# Processing Record 42 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 9 | maldonado
# Processing Record 44 of Set 9 | rudnya
# Processing Record 45 of Set 9 | urumqi
# Processing Record 46 of Set 9 | nemuro
# Processing Record 47 of Set 9 | olinda
# Processing Record 48 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 9 | zhigansk
# Processing Record 50 of Set 9 | auki
# Processing Record 1 of Set 10 | xam nua
# Processing Record 2 of Set 10 | mizdah
# Processing Record 3 of Set 10 | porto walter
# Processing Record 4 of Set 10 | whitehorse
# Processing Record 5 of Set 10 | sidi ali
# Processing Record 6 of Set 10 | grand gaube
# Processing Record 7 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 8 of Set 10 | labuhan
# Processing Record 9 of Set 10 | sheoganj
# Processing Record 10 of Set 10 | acajutla
# Processing Record 11 of Set 10 | havre-saint-pierre
# Processing Record 12 of Set 10 | yerbogachen
# Processing Record 13 of Set 10 | raga
# Processing Record 14 of Set 10 | hamadan
# Processing Record 15 of Set 10 | la plata
# Processing Record 16 of Set 10 | maragogi
# Processing Record 17 of Set 10 | duekoue
# Processing Record 18 of Set 10 | port pirie
# Processing Record 19 of Set 10 | nishihara
# Processing Record 20 of Set 10 | rorvik
# Processing Record 21 of Set 10 | tazmalt
# Processing Record 22 of Set 10 | pati
# Processing Record 23 of Set 10 | catalao
# Processing Record 24 of Set 10 | bardiyah
# Processing Record 25 of Set 10 | leningradskiy
# Processing Record 26 of Set 10 | okakarara
# Processing Record 27 of Set 10 | hirara
# Processing Record 28 of Set 10 | conde
# Processing Record 29 of Set 10 | visnes
# Processing Record 30 of Set 10 | takoradi
# Processing Record 31 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 32 of Set 10 | amlame
# Processing Record 33 of Set 10 | yabrud
# Processing Record 34 of Set 10 | ilulissat
# Processing Record 35 of Set 10 | gayny
# Processing Record 36 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 37 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 38 of Set 10 | guadalupe y calvo
# Processing Record 39 of Set 10 | yumen
# Processing Record 40 of Set 10 | fowa
# Processing Record 41 of Set 10 | sarakhs
# Processing Record 42 of Set 10 | lakatoro
# Processing Record 43 of Set 10 | zabol
# Processing Record 44 of Set 10 | viedma
# Processing Record 45 of Set 10 | barsi
# Processing Record 46 of Set 10 | nasirabad
# Processing Record 47 of Set 10 | two hills
# Processing Record 48 of Set 10 | mbandaka
# Processing Record 49 of Set 10 | mayo
# Processing Record 50 of Set 10 | colomi
# Processing Record 1 of Set 11 | severomuysk
# Processing Record 2 of Set 11 | ancud
# Processing Record 3 of Set 11 | chulman
# Processing Record 4 of Set 11 | jizan
# Processing Record 5 of Set 11 | yantal
# Processing Record 6 of Set 11 | antsohihy
# Processing Record 7 of Set 11 | byron bay
# Processing Record 8 of Set 11 | dunedin
# Processing Record 9 of Set 11 | puerto del rosario
# Processing Record 10 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 11 | lyskovo
# Processing Record 12 of Set 11 | merauke
# Processing Record 13 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 11 | namibe
# Processing Record 15 of Set 11 | mogadishu
# Processing Record 16 of Set 11 | luoyang
# Processing Record 17 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 11 | lata
# Processing Record 19 of Set 11 | vyshneve
# Processing Record 20 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 21 of Set 11 | batagay-alyta
# Processing Record 22 of Set 11 | uyskoye
# Processing Record 23 of Set 11 | sioux lookout
# Processing Record 24 of Set 11 | vetluzhskiy
# Processing Record 25 of Set 11 | naze
# Processing Record 26 of Set 11 | glace bay
# Processing Record 27 of Set 11 | faya
# Processing Record 28 of Set 11 | matranovak
# Processing Record 29 of Set 11 | estancia
# Processing Record 30 of Set 11 | chapais
# Processing Record 31 of Set 11 | malpe
# Processing Record 32 of Set 11 | caravelas
# Processing Record 33 of Set 11 | manzhouli
# Processing Record 34 of Set 11 | khandyga
# Processing Record 35 of Set 11 | makungu
# Processing Record 36 of Set 11 | arrecife
# Processing Record 37 of Set 11 | mahajanga
# Processing Record 38 of Set 11 | ixtapa
# Processing Record 39 of Set 11 | arlit
# Processing Record 40 of Set 11 | pittsfield
# Processing Record 41 of Set 11 | bambous virieux
# Processing Record 42 of Set 11 | rosehearty
# Processing Record 43 of Set 11 | flinders
# Processing Record 44 of Set 11 | morgan city
# Processing Record 45 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 11 | kuytun
# Processing Record 47 of Set 11 | maltahohe
# Processing Record 48 of Set 11 | effingham
# Processing Record 49 of Set 11 | morant bay
# Processing Record 50 of Set 11 | languyan
# Processing Record 1 of Set 12 | port macquarie
# Processing Record 2 of Set 12 | jieshi
# Processing Record 3 of Set 12 | bonthe
# Processing Record 4 of Set 12 | devils lake
# Processing Record 5 of Set 12 | jeremoabo
# Processing Record 6 of Set 12 | rocha
# Processing Record 7 of Set 12 | chornukhy
# Processing Record 8 of Set 12 | thaba-tseka
# Processing Record 9 of Set 12 | collie
# Processing Record 10 of Set 12 | chicama
# Processing Record 11 of Set 12 | shenjiamen
# Processing Record 12 of Set 12 | vostok
# Processing Record 13 of Set 12 | suluq
# Processing Record 14 of Set 12 | sun valley
# Processing Record 15 of Set 12 | savannah bight
# Processing Record 16 of Set 12 | north bend
# Processing Record 17 of Set 12 | karratha
# Processing Record 18 of Set 12 | mackay
# Processing Record 19 of Set 12 | plettenberg bay
# Processing Record 20 of Set 12 | hualmay
# Processing Record 21 of Set 12 | northam
# Processing Record 22 of Set 12 | solnechnyy
# Processing Record 23 of Set 12 | zaysan
# Processing Record 24 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 12 | cardston
# Processing Record 26 of Set 12 | bela
# Processing Record 27 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 28 of Set 12 | chernyshevskiy
# Processing Record 29 of Set 12 | husavik
# Processing Record 30 of Set 12 | salalah
# Processing Record 31 of Set 12 | chapleau
# Processing Record 32 of Set 12 | little current
# Processing Record 33 of Set 12 | yulara
# Processing Record 34 of Set 12 | gatton
# Processing Record 35 of Set 12 | sept-iles
# Processing Record 36 of Set 12 | coquimbo
# Processing Record 37 of Set 12 | akureyri
# Processing Record 38 of Set 12 | margate
# Processing Record 39 of Set 12 | luancheng
# Processing Record 40 of Set 12 | gravelbourg
# Processing Record 41 of Set 12 | yamada
# Processing Record 42 of Set 12 | mount gambier
# Processing Record 43 of Set 12 | brae
# Processing Record 44 of Set 12 | ballina
# Processing Record 45 of Set 12 | panama city
# Processing Record 46 of Set 12 | vinh yen
# Processing Record 47 of Set 12 | cirebon
# Processing Record 48 of Set 12 | agadir
# Processing Record 49 of Set 12 | baykit
# Processing Record 50 of Set 12 | bontang
# Processing Record 1 of Set 13 | mount isa
# Processing Record 2 of Set 13 | guanica
# Processing Record 3 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 4 of Set 13 | kaabong
# Processing Record 5 of Set 13 | casablanca
# Processing Record 6 of Set 13 | naron
# Processing Record 7 of Set 13 | zhenlai
# Processing Record 8 of Set 13 | coahuayana
# Processing Record 9 of Set 13 | komsomolskiy
# Processing Record 10 of Set 13 | shaowu
# Processing Record 11 of Set 13 | svetlogorsk
# Processing Record 12 of Set 13 | chumikan
# Processing Record 13 of Set 13 | kavieng
# Processing Record 14 of Set 13 | necochea
# Processing Record 15 of Set 13 | ocampo
# Processing Record 16 of Set 13 | laguna
# Processing Record 17 of Set 13 | lyngdal
# Processing Record 18 of Set 13 | la maddalena
# Processing Record 19 of Set 13 | riachao das neves
# Processing Record 20 of Set 13 | ca mau
# Processing Record 21 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 22 of Set 13 | ambilobe
# Processing Record 23 of Set 13 | acandi
# Processing Record 24 of Set 13 | boa vista
# Processing Record 25 of Set 13 | marzuq
# Processing Record 26 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 13 | xilagani
# Processing Record 28 of Set 13 | barroui
# City not found. Skipping...
# Processing Record 29 of Set 13 | vilyuysk
# Processing Record 30 of Set 13 | deggendorf
# Processing Record 31 of Set 13 | coutances
# Processing Record 32 of Set 13 | laguna de perlas
# Processing Record 33 of Set 13 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 13 | taltal
# Processing Record 35 of Set 13 | vizinga
# Processing Record 36 of Set 13 | ulkan
# Processing Record 37 of Set 13 | muros
# Processing Record 38 of Set 13 | pimentel
# Processing Record 39 of Set 13 | villanueva de la serena
# Processing Record 40 of Set 13 | mitchell
# Processing Record 41 of Set 13 | puerto baquerizo moreno
# Processing Record 42 of Set 13 | alexandria
# Processing Record 43 of Set 13 | aksarka
# Processing Record 44 of Set 13 | sivas
# Processing Record 45 of Set 13 | bubaque
# Processing Record 46 of Set 13 | iracoubo
# Processing Record 47 of Set 13 | chifeng
# Processing Record 48 of Set 13 | penzance
# Processing Record 49 of Set 13 | brazzaville
# Processing Record 50 of Set 13 | tevriz
# Processing Record 1 of Set 14 | ambunti
# Processing Record 2 of Set 14 | miyako
# Processing Record 3 of Set 14 | cuamba
# Processing Record 4 of Set 14 | halvad
# Processing Record 5 of Set 14 | ushirombo
# Processing Record 6 of Set 14 | sawtell
# Processing Record 7 of Set 14 | farso
# Processing Record 8 of Set 14 | port blair
# Processing Record 9 of Set 14 | qaqortoq
# Processing Record 10 of Set 14 | amalfi
# Processing Record 11 of Set 14 | karasjok
# Processing Record 12 of Set 14 | tessalit
# Processing Record 13 of Set 14 | arkhangelos
# City not found. Skipping...
# Processing Record 14 of Set 14 | matara
# Processing Record 15 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 16 of Set 14 | borba
# Processing Record 17 of Set 14 | fortuna foothills
# Processing Record 18 of Set 14 | tadine
# Processing Record 19 of Set 14 | pamplona
# Processing Record 20 of Set 14 | kahului
# Processing Record 21 of Set 14 | verkhoyansk
# Processing Record 22 of Set 14 | porto novo
# Processing Record 23 of Set 14 | novaci
# Processing Record 24 of Set 14 | avera
# Processing Record 25 of Set 14 | taft
# Processing Record 26 of Set 14 | dogondoutchi
# Processing Record 27 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 14 | upata
# Processing Record 29 of Set 14 | vinh
# Processing Record 30 of Set 14 | along
# Processing Record 31 of Set 14 | sonqor
# Processing Record 32 of Set 14 | sayalgudi
# City not found. Skipping...
# Processing Record 33 of Set 14 | rancho palos verdes
# Processing Record 34 of Set 14 | hervey bay
# Processing Record 35 of Set 14 | tucuman
# Processing Record 36 of Set 14 | adeje
# Processing Record 37 of Set 14 | krasnoselkup
# Processing Record 38 of Set 14 | sao joao da barra
# Processing Record 39 of Set 14 | los algarrobos
# Processing Record 40 of Set 14 | kang
# Processing Record 41 of Set 14 | carasova
# Processing Record 42 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 14 | sabang
# Processing Record 44 of Set 14 | kaeo
# Processing Record 45 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 46 of Set 14 | ferkessedougou
# Processing Record 47 of Set 14 | garowe
# Processing Record 48 of Set 14 | pelym
# Processing Record 49 of Set 14 | walvis bay
# Processing Record 50 of Set 14 | fort nelson
# Processing Record 1 of Set 15 | chudniv
# Processing Record 2 of Set 15 | america dourada
# Processing Record 3 of Set 15 | kroya
# Processing Record 4 of Set 15 | la crosse
# Processing Record 5 of Set 15 | nouakchott
# Processing Record 6 of Set 15 | ginir
# Processing Record 7 of Set 15 | eyl
# Processing Record 8 of Set 15 | santa cruz
# Processing Record 9 of Set 15 | isla vista
# Processing Record 10 of Set 15 | tornio
# Processing Record 11 of Set 15 | marand
# Processing Record 12 of Set 15 | carutapera
# Processing Record 13 of Set 15 | tautira
# Processing Record 14 of Set 15 | mumford
# Processing Record 15 of Set 15 | oktyabrskiy
# Processing Record 16 of Set 15 | colares
# Processing Record 17 of Set 15 | kailua
# Processing Record 18 of Set 15 | grants
# Processing Record 19 of Set 15 | dhidhdhoo
# Processing Record 20 of Set 15 | labytnangi
# Processing Record 21 of Set 15 | antalaha
# Processing Record 22 of Set 15 | atar
# Processing Record 23 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 15 | ushtobe
# Processing Record 25 of Set 15 | korla
# Processing Record 26 of Set 15 | benguela
# Processing Record 27 of Set 15 | kisangani
# Processing Record 28 of Set 15 | rabat
# Processing Record 29 of Set 15 | suntar
# Processing Record 30 of Set 15 | rio branco
# Processing Record 31 of Set 15 | kemijarvi
# Processing Record 32 of Set 15 | goderich
# Processing Record 33 of Set 15 | kachiry
# Processing Record 34 of Set 15 | quime
# Processing Record 35 of Set 15 | salima
# Processing Record 36 of Set 15 | grindavik
# Processing Record 37 of Set 15 | general elizardo aquino
# Processing Record 38 of Set 15 | rio gallegos
# Processing Record 39 of Set 15 | novyy urengoy
# Processing Record 40 of Set 15 | moree
# Processing Record 41 of Set 15 | rapid valley
# Processing Record 42 of Set 15 | ambulu
# Processing Record 43 of Set 15 | gardez
# Processing Record 44 of Set 15 | ankazoabo
# Processing Record 45 of Set 15 | linqiong
# Processing Record 46 of Set 15 | dudinka
# Processing Record 47 of Set 15 | verkhnyaya inta
# Processing Record 48 of Set 15 | mandalgovi
# Processing Record 49 of Set 15 | saint-pierre
# Processing Record 50 of Set 15 | gigmoto
# Processing Record 1 of Set 16 | christchurch
# Processing Record 2 of Set 16 | pimenta bueno
# Processing Record 3 of Set 16 | puerto colombia
# Processing Record 4 of Set 16 | zachagansk
# City not found. Skipping...
# Processing Record 5 of Set 16 | coihueco
# Processing Record 6 of Set 16 | afareaitu
# Processing Record 7 of Set 16 | padang
# Processing Record 8 of Set 16 | waingapu
# Processing Record 9 of Set 16 | south lake tahoe
# Processing Record 10 of Set 16 | goteborg
# City not found. Skipping...
# Processing Record 11 of Set 16 | oliveira
# Processing Record 12 of Set 16 | chongwe
# Processing Record 13 of Set 16 | surt
# Processing Record 14 of Set 16 | suamico
# Processing Record 15 of Set 16 | la libertad
# Processing Record 16 of Set 16 | dali
# Processing Record 17 of Set 16 | kungurtug
# Processing Record 18 of Set 16 | tiznit
# Processing Record 19 of Set 16 | izhmorskiy
# Processing Record 20 of Set 16 | abonnema
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Saldanha      ZA -33.0117   17.9442     50.05        74
# 1            Estelle      US  29.8458  -90.1067     86.00        72
# 2       Punta Arenas      CL -53.1500  -70.9167     44.71        57
# 3             Atuona      PF  -9.8000 -139.0333     77.81        75
# 4          Geraldton      AU -28.7667  114.6000     48.61        87
# 5           Cidreira      BR -30.1811  -50.2056     64.06        94
# 6  Saint Paul Harbor      US  57.7900 -152.4072     42.66        49
# 7       Lake Charles      US  30.2131  -93.2044     87.78        63
# 8          Esperance      AU -33.8667  121.9000     42.64        71
# 9               Aden      YE  12.7794   45.0367     88.00        62
#
#    Cloudiness  Wind Speed Current Description
# 0           0       24.63           clear sky
# 1          98        1.99     overcast clouds
# 2           0       34.52           clear sky
# 3          14       17.49          few clouds
# 4          40        9.22    scattered clouds
# 5         100       14.61     overcast clouds
# 6           1        7.40           clear sky
# 7          40        0.00    scattered clouds
# 8          45       11.12    scattered clouds
# 9          67        8.25       broken clouds

# %%
pd.options.display.float_format = "{:.2f}".format
city_data_df.head(10)
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Saldanha      ZA -33.01   17.94     50.05        74           0
# 1            Estelle      US  29.85  -90.11     86.00        72          98
# 2       Punta Arenas      CL -53.15  -70.92     44.71        57           0
# 3             Atuona      PF  -9.80 -139.03     77.81        75          14
# 4          Geraldton      AU -28.77  114.60     48.61        87          40
# 5           Cidreira      BR -30.18  -50.21     64.06        94         100
# 6  Saint Paul Harbor      US  57.79 -152.41     42.66        49           1
# 7       Lake Charles      US  30.21  -93.20     87.78        63          40
# 8          Esperance      AU -33.87  121.90     42.64        71          45
# 9               Aden      YE  12.78   45.04     88.00        62          67
#
#    Wind Speed Current Description
# 0       24.63           clear sky
# 1        1.99     overcast clouds
# 2       34.52           clear sky
# 3       17.49          few clouds
# 4        9.22    scattered clouds
# 5       14.61     overcast clouds
# 6        7.40           clear sky
# 7        0.00    scattered clouds
# 8       11.12    scattered clouds
# 9        8.25       broken clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")

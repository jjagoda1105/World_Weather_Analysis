# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0089b060fc68e7a641e9237dab69fbc2

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0089b060fc68e7a641e9237dab69fbc2&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 3 of Set 15 | torbay
# Processing Record 4 of Set 15 | rikitea
# Processing Record 5 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 15 | hobart
# Processing Record 8 of Set 15 | ostrovnoy
# Processing Record 9 of Set 15 | ikeda
# Processing Record 10 of Set 15 | bintulu
# Processing Record 11 of Set 15 | jamestown
# Processing Record 12 of Set 15 | campo grande
# Processing Record 13 of Set 15 | lavrentiya
# Processing Record 14 of Set 15 | hithadhoo
# Processing Record 15 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 15 | tuatapere
# Processing Record 18 of Set 15 | codrington
# Processing Record 19 of Set 15 | yellowknife
# Processing Record 20 of Set 15 | sungaipenuh
# Processing Record 21 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 15 | jalingo
# Processing Record 23 of Set 15 | hasaki
# Processing Record 24 of Set 15 | vaini
# Processing Record 25 of Set 15 | altay
# Processing Record 26 of Set 15 | yenagoa
# Processing Record 27 of Set 15 | dali
# Processing Record 28 of Set 15 | new norfolk
# Processing Record 29 of Set 15 | waingapu
# Processing Record 30 of Set 15 | ushuaia
# Processing Record 31 of Set 15 | ribeira grande
# Processing Record 32 of Set 15 | khatanga
# Processing Record 33 of Set 15 | kodiak
# Processing Record 34 of Set 15 | east london
# Processing Record 35 of Set 15 | kaitangata
# Processing Record 36 of Set 15 | morondava
# Processing Record 37 of Set 15 | arraial do cabo
# Processing Record 38 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 15 | parainen
# Processing Record 40 of Set 15 | sitka
# Processing Record 41 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 15 | barrow
# Processing Record 43 of Set 15 | hilo
# Processing Record 44 of Set 15 | victor harbor
# Processing Record 45 of Set 15 | bengkulu
# Processing Record 46 of Set 15 | saint-francois
# Processing Record 47 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 15 | jalu
# Processing Record 49 of Set 15 | zhob
# Processing Record 50 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 16 | port hedland
# Processing Record 2 of Set 16 | yuty
# Processing Record 3 of Set 16 | srednekolymsk
# Processing Record 4 of Set 16 | katsuura
# Processing Record 5 of Set 16 | alyangula
# Processing Record 6 of Set 16 | madang
# Processing Record 7 of Set 16 | pangnirtung
# Processing Record 8 of Set 16 | punta arenas
# Processing Record 9 of Set 16 | beloha
# Processing Record 10 of Set 16 | det udom
# Processing Record 11 of Set 16 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 16 | caibarien
# Processing Record 13 of Set 16 | busselton
# Processing Record 14 of Set 16 | qaanaaq
# Processing Record 15 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 16 | puerto ayora
# Processing Record 17 of Set 16 | isangel
# Processing Record 18 of Set 16 | tagawa
# Processing Record 19 of Set 16 | pozo colorado
# Processing Record 20 of Set 16 | bambous virieux
# Processing Record 21 of Set 16 | cape town
# Processing Record 22 of Set 16 | ponta do sol
# Processing Record 23 of Set 16 | castro
# Processing Record 24 of Set 16 | charlestown
# Processing Record 25 of Set 16 | nemuro
# Processing Record 26 of Set 16 | port elizabeth
# Processing Record 27 of Set 16 | namibe
# Processing Record 28 of Set 16 | cuamba
# Processing Record 29 of Set 16 | seymchan
# Processing Record 30 of Set 16 | morristown
# Processing Record 31 of Set 16 | te anau
# Processing Record 32 of Set 16 | santa maria
# Processing Record 33 of Set 16 | butaritari
# Processing Record 34 of Set 16 | avarua
# Processing Record 35 of Set 16 | saint-philippe
# Processing Record 36 of Set 16 | iqaluit
# Processing Record 37 of Set 16 | huntingdon
# Processing Record 38 of Set 16 | santa luzia
# Processing Record 39 of Set 16 | kapaa
# Processing Record 40 of Set 16 | paamiut
# Processing Record 41 of Set 16 | jacareacanga
# Processing Record 42 of Set 16 | bluff
# Processing Record 43 of Set 16 | mont-de-marsan
# Processing Record 44 of Set 16 | atuona
# Processing Record 45 of Set 16 | tasiilaq
# Processing Record 46 of Set 16 | albany
# Processing Record 47 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 16 | bolshaya glushitsa
# Processing Record 50 of Set 16 | severo-kurilsk
# Processing Record 1 of Set 17 | haverfordwest
# Processing Record 2 of Set 17 | oneida
# Processing Record 3 of Set 17 | benghazi
# Processing Record 4 of Set 17 | lagoa
# Processing Record 5 of Set 17 | port alfred
# Processing Record 6 of Set 17 | englewood
# Processing Record 7 of Set 17 | puerto ayacucho
# Processing Record 8 of Set 17 | kununurra
# Processing Record 9 of Set 17 | chimbote
# Processing Record 10 of Set 17 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 17 | douentza
# Processing Record 12 of Set 17 | stornoway
# Processing Record 13 of Set 17 | ngunguru
# Processing Record 14 of Set 17 | vestmannaeyjar
# Processing Record 15 of Set 17 | malko tarnovo
# Processing Record 16 of Set 17 | burkhala
# City not found. Skipping...
# Processing Record 17 of Set 17 | sao filipe
# Processing Record 18 of Set 17 | mbaiki
# Processing Record 19 of Set 17 | kigoma
# Processing Record 20 of Set 17 | longyearbyen
# Processing Record 21 of Set 17 | chokurdakh
# Processing Record 22 of Set 17 | pecos
# Processing Record 23 of Set 17 | ust-tarka
# Processing Record 24 of Set 17 | upernavik
# Processing Record 25 of Set 17 | hermanus
# Processing Record 26 of Set 17 | mataura
# Processing Record 27 of Set 17 | broome
# Processing Record 28 of Set 17 | tura
# Processing Record 29 of Set 17 | lebu
# Processing Record 30 of Set 17 | senanga
# Processing Record 31 of Set 17 | taguatinga
# Processing Record 32 of Set 17 | bredasdorp
# Processing Record 33 of Set 17 | raga
# City not found. Skipping...
# Processing Record 34 of Set 17 | fergus falls
# Processing Record 35 of Set 17 | saldanha
# Processing Record 36 of Set 17 | areado
# Processing Record 37 of Set 17 | seoul
# Processing Record 38 of Set 17 | tarabuco
# Processing Record 39 of Set 17 | hervey bay
# Processing Record 40 of Set 17 | puerto leguizamo
# Processing Record 41 of Set 17 | port hardy
# Processing Record 42 of Set 17 | vuktyl
# Processing Record 43 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 17 | tuktoyaktuk
# Processing Record 45 of Set 17 | asosa
# Processing Record 46 of Set 17 | aklavik
# Processing Record 47 of Set 17 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 17 | oskarshamn
# Processing Record 49 of Set 17 | rocha
# Processing Record 50 of Set 17 | lake havasu city
# Processing Record 1 of Set 18 | oshkosh
# Processing Record 2 of Set 18 | cayenne
# Processing Record 3 of Set 18 | belaya gora
# Processing Record 4 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 18 | saskylakh
# Processing Record 6 of Set 18 | aripuana
# Processing Record 7 of Set 18 | azimur
# City not found. Skipping...
# Processing Record 8 of Set 18 | nanga eboko
# Processing Record 9 of Set 18 | airai
# Processing Record 10 of Set 18 | maldonado
# Processing Record 11 of Set 18 | mar del plata
# Processing Record 12 of Set 18 | hofn
# Processing Record 13 of Set 18 | krasnoselkup
# Processing Record 14 of Set 18 | palmer
# Processing Record 15 of Set 18 | agua verde
# Processing Record 16 of Set 18 | chuy
# Processing Record 17 of Set 18 | zhigansk
# Processing Record 18 of Set 18 | shingu
# Processing Record 19 of Set 18 | milkovo
# Processing Record 20 of Set 18 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 18 | bani
# Processing Record 22 of Set 18 | souillac
# Processing Record 23 of Set 18 | ortakoy
# Processing Record 24 of Set 18 | barra patuca
# Processing Record 25 of Set 18 | high level
# Processing Record 26 of Set 18 | nikolskoye
# Processing Record 27 of Set 18 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 18 | chicama
# Processing Record 29 of Set 18 | port augusta
# Processing Record 30 of Set 18 | ketchikan
# Processing Record 31 of Set 18 | filadelfia
# Processing Record 32 of Set 18 | ca mau
# Processing Record 33 of Set 18 | kartaly
# Processing Record 34 of Set 18 | georgetown
# Processing Record 35 of Set 18 | norman wells
# Processing Record 36 of Set 18 | gazli
# Processing Record 37 of Set 18 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 18 | klaksvik
# Processing Record 39 of Set 18 | grindavik
# Processing Record 40 of Set 18 | sackville
# Processing Record 41 of Set 18 | tapes
# Processing Record 42 of Set 18 | victoria
# Processing Record 43 of Set 18 | rosario
# Processing Record 44 of Set 18 | saint george
# Processing Record 45 of Set 18 | hilton head island
# Processing Record 46 of Set 18 | pisco
# Processing Record 47 of Set 18 | sakaiminato
# Processing Record 48 of Set 18 | moree
# Processing Record 49 of Set 18 | agadez
# Processing Record 50 of Set 18 | formoso do araguaia
# City not found. Skipping...
# Processing Record 1 of Set 19 | menongue
# Processing Record 2 of Set 19 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 19 | naifaru
# Processing Record 4 of Set 19 | carnarvon
# Processing Record 5 of Set 19 | ancud
# Processing Record 6 of Set 19 | cherskiy
# Processing Record 7 of Set 19 | vardo
# Processing Record 8 of Set 19 | geraldton
# Processing Record 9 of Set 19 | stonewall
# Processing Record 10 of Set 19 | yankton
# Processing Record 11 of Set 19 | da nang
# Processing Record 12 of Set 19 | fortuna
# Processing Record 13 of Set 19 | necochea
# Processing Record 14 of Set 19 | innisfail
# Processing Record 15 of Set 19 | zeya
# Processing Record 16 of Set 19 | kovdor
# Processing Record 17 of Set 19 | moron
# Processing Record 18 of Set 19 | turukhansk
# Processing Record 19 of Set 19 | leningradskiy
# Processing Record 20 of Set 19 | claveria
# Processing Record 21 of Set 19 | kintinku
# Processing Record 22 of Set 19 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 19 | aksu
# Processing Record 24 of Set 19 | nantucket
# Processing Record 25 of Set 19 | bandarbeyla
# Processing Record 26 of Set 19 | shemgang
# Processing Record 27 of Set 19 | bondoukou
# Processing Record 28 of Set 19 | boa vista
# Processing Record 29 of Set 19 | mujiayingzi
# Processing Record 30 of Set 19 | provideniya
# Processing Record 31 of Set 19 | kieta
# Processing Record 32 of Set 19 | nouadhibou
# Processing Record 33 of Set 19 | yermish
# Processing Record 34 of Set 19 | husavik
# Processing Record 35 of Set 19 | sept-iles
# Processing Record 36 of Set 19 | deputatskiy
# Processing Record 37 of Set 19 | tateyama
# Processing Record 38 of Set 19 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 19 | waipawa
# Processing Record 40 of Set 19 | tiksi
# Processing Record 41 of Set 19 | broken hill
# Processing Record 42 of Set 19 | balikpapan
# Processing Record 43 of Set 19 | natal
# Processing Record 44 of Set 19 | mount gambier
# Processing Record 45 of Set 19 | komsomolskiy
# Processing Record 46 of Set 19 | thompson
# Processing Record 47 of Set 19 | cao bang
# Processing Record 48 of Set 19 | marawi
# Processing Record 49 of Set 19 | vidim
# Processing Record 50 of Set 19 | bainbridge
# Processing Record 1 of Set 20 | junagarh
# Processing Record 2 of Set 20 | altrincham
# Processing Record 3 of Set 20 | narsaq
# Processing Record 4 of Set 20 | san joaquin
# Processing Record 5 of Set 20 | boksitogorsk
# Processing Record 6 of Set 20 | sandpoint
# Processing Record 7 of Set 20 | yulara
# Processing Record 8 of Set 20 | pochutla
# Processing Record 9 of Set 20 | yuncheng
# Processing Record 10 of Set 20 | ust-omchug
# Processing Record 11 of Set 20 | koshki
# Processing Record 12 of Set 20 | solnechnyy
# Processing Record 13 of Set 20 | nouakchott
# Processing Record 14 of Set 20 | san patricio
# Processing Record 15 of Set 20 | carson city
# Processing Record 16 of Set 20 | laranjeiras do sul
# Processing Record 17 of Set 20 | pinawa
# Processing Record 18 of Set 20 | ewa beach
# Processing Record 19 of Set 20 | fakel
# Processing Record 20 of Set 20 | aguimes
# Processing Record 21 of Set 20 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 20 | mbini
# Processing Record 23 of Set 20 | hami
# Processing Record 24 of Set 20 | henties bay
# Processing Record 25 of Set 20 | poum
# Processing Record 26 of Set 20 | katherine
# Processing Record 27 of Set 20 | sabang
# Processing Record 28 of Set 20 | natitingou
# Processing Record 29 of Set 20 | dong hoi
# Processing Record 30 of Set 20 | hambantota
# Processing Record 31 of Set 20 | kutum
# Processing Record 32 of Set 20 | panique
# Processing Record 33 of Set 20 | cidreira
# Processing Record 34 of Set 20 | meulaboh
# Processing Record 35 of Set 20 | naze
# Processing Record 36 of Set 20 | kruisfontein
# Processing Record 37 of Set 20 | tupik
# Processing Record 38 of Set 20 | camacupa
# Processing Record 39 of Set 20 | kralendijk
# Processing Record 40 of Set 20 | tamuin
# Processing Record 41 of Set 20 | mackay
# Processing Record 42 of Set 20 | viladecans
# Processing Record 43 of Set 20 | ponta pora
# Processing Record 44 of Set 20 | esperance
# Processing Record 45 of Set 20 | domingos martins
# Processing Record 46 of Set 20 | malinovskiy
# Processing Record 47 of Set 20 | mezhova
# Processing Record 48 of Set 20 | valga
# Processing Record 49 of Set 20 | kenai
# Processing Record 50 of Set 20 | galesong
# Processing Record 1 of Set 21 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 21 | bosaso
# Processing Record 3 of Set 21 | kawalu
# Processing Record 4 of Set 21 | pitimbu
# Processing Record 5 of Set 21 | nishihara
# Processing Record 6 of Set 21 | oudtshoorn
# Processing Record 7 of Set 21 | sayyan
# Processing Record 8 of Set 21 | brownwood
# Processing Record 9 of Set 21 | port macquarie
# Processing Record 10 of Set 21 | flinders
# Processing Record 11 of Set 21 | shirvan
# Processing Record 12 of Set 21 | lamar
# Processing Record 13 of Set 21 | cabo san lucas
# Processing Record 14 of Set 21 | ramasukha
# City not found. Skipping...
# Processing Record 15 of Set 21 | port blair
# Processing Record 16 of Set 21 | sorland
# Processing Record 17 of Set 21 | tessalit
# Processing Record 18 of Set 21 | varena
# Processing Record 19 of Set 21 | adrar
# Processing Record 20 of Set 21 | san quintin
# Processing Record 21 of Set 21 | tucuman
# Processing Record 22 of Set 21 | manavalakurichi
# Processing Record 23 of Set 21 | oyama
# Processing Record 24 of Set 21 | yokadouma
# Processing Record 25 of Set 21 | progreso
# Processing Record 26 of Set 21 | road town
# Processing Record 27 of Set 21 | ust-nera
# Processing Record 28 of Set 21 | maceio
# Processing Record 29 of Set 21 | miri
# Processing Record 30 of Set 21 | kavieng
# Processing Record 31 of Set 21 | ziyamet
# City not found. Skipping...
# Processing Record 32 of Set 21 | mormugao
# Processing Record 33 of Set 21 | baykit
# Processing Record 34 of Set 21 | belmopan
# Processing Record 35 of Set 21 | bathsheba
# Processing Record 36 of Set 21 | nome
# Processing Record 37 of Set 21 | tautira
# Processing Record 38 of Set 21 | tual
# Processing Record 39 of Set 21 | maltahohe
# Processing Record 40 of Set 21 | talnakh
# Processing Record 41 of Set 21 | lompoc
# Processing Record 42 of Set 21 | ricany
# Processing Record 43 of Set 21 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 21 | aquiraz
# Processing Record 45 of Set 21 | del rio
# Processing Record 46 of Set 21 | povenets
# Processing Record 47 of Set 21 | tari
# Processing Record 48 of Set 21 | bikaner
# Processing Record 49 of Set 21 | valparaiso
# Processing Record 50 of Set 21 | poronaysk
# Processing Record 1 of Set 22 | tel aviv-yafo
# Processing Record 2 of Set 22 | salalah
# Processing Record 3 of Set 22 | ternovka
# Processing Record 4 of Set 22 | dwarka
# Processing Record 5 of Set 22 | chaumont
# Processing Record 6 of Set 22 | saint-pierre
# Processing Record 7 of Set 22 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 22 | tynda
# Processing Record 9 of Set 22 | labuhan
# Processing Record 10 of Set 22 | gizo
# Processing Record 11 of Set 22 | bereda
# Processing Record 12 of Set 22 | umm lajj
# Processing Record 13 of Set 22 | ahuimanu
# Processing Record 14 of Set 22 | taitung
# Processing Record 15 of Set 22 | havre-saint-pierre
# Processing Record 16 of Set 22 | redmond
# Processing Record 17 of Set 22 | solntsevo
# Processing Record 18 of Set 22 | visnes
# Processing Record 19 of Set 22 | praia da vitoria
# Processing Record 20 of Set 22 | antofagasta
# Processing Record 21 of Set 22 | muros
# Processing Record 22 of Set 22 | vestmanna
# Processing Record 23 of Set 22 | shaunavon
# Processing Record 24 of Set 22 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 22 | sasolburg
# Processing Record 26 of Set 22 | candelaria
# Processing Record 27 of Set 22 | shimoda
# Processing Record 28 of Set 22 | moose factory
# Processing Record 29 of Set 22 | manado
# Processing Record 30 of Set 22 | yaan
# Processing Record 31 of Set 22 | hualmay
# Processing Record 32 of Set 22 | samana
# Processing Record 33 of Set 22 | trincomalee
# Processing Record 34 of Set 22 | grand gaube
# Processing Record 35 of Set 22 | san jose
# Processing Record 36 of Set 22 | taoudenni
# Processing Record 37 of Set 22 | itoman
# Processing Record 38 of Set 22 | surt
# Processing Record 39 of Set 22 | lookan
# Processing Record 40 of Set 22 | kapoeta
# Processing Record 41 of Set 22 | bad nauheim
# Processing Record 42 of Set 22 | linxia
# Processing Record 43 of Set 22 | lorengau
# Processing Record 44 of Set 22 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 22 | taltal
# Processing Record 46 of Set 22 | portland
# Processing Record 47 of Set 22 | armeria
# Processing Record 48 of Set 22 | jibuti
# Processing Record 49 of Set 22 | biak
# Processing Record 50 of Set 22 | zapolyarnyy
# Processing Record 1 of Set 23 | buariki
# City not found. Skipping...
# Processing Record 2 of Set 23 | skjervoy
# Processing Record 3 of Set 23 | manggar
# Processing Record 4 of Set 23 | goderich
# Processing Record 5 of Set 23 | zolotinka
# City not found. Skipping...
# Processing Record 6 of Set 23 | korla
# Processing Record 7 of Set 23 | porto novo
# Processing Record 8 of Set 23 | arawa
# Processing Record 9 of Set 23 | buta
# Processing Record 10 of Set 23 | tarko-sale
# Processing Record 11 of Set 23 | yakeshi
# Processing Record 12 of Set 23 | assiniboia
# Processing Record 13 of Set 23 | ilulissat
# Processing Record 14 of Set 23 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 23 | sao felix do xingu
# Processing Record 16 of Set 23 | diapaga
# Processing Record 17 of Set 23 | sambava
# Processing Record 18 of Set 23 | dingle
# Processing Record 19 of Set 23 | sioux lookout
# Processing Record 20 of Set 23 | nizhniy kuranakh
# Processing Record 21 of Set 23 | cuenca
# Processing Record 22 of Set 23 | lingao
# Processing Record 23 of Set 23 | puerto palomas
# Processing Record 24 of Set 23 | trinidad
# Processing Record 25 of Set 23 | ust-kut
# Processing Record 26 of Set 23 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 23 | tabas
# Processing Record 28 of Set 23 | anori
# Processing Record 29 of Set 23 | san cristobal
# Processing Record 30 of Set 23 | san angelo
# Processing Record 31 of Set 23 | sechura
# Processing Record 32 of Set 23 | hailey
# Processing Record 33 of Set 23 | zhuanghe
# Processing Record 34 of Set 23 | shaowu
# Processing Record 35 of Set 23 | marsa matruh
# Processing Record 36 of Set 23 | santa ines
# Processing Record 37 of Set 23 | samarai
# Processing Record 38 of Set 23 | omsukchan
# Processing Record 39 of Set 23 | hunza
# City not found. Skipping...
# Processing Record 40 of Set 23 | port lincoln
# Processing Record 41 of Set 23 | tongzi
# Processing Record 42 of Set 23 | mahanoro
# Processing Record 43 of Set 23 | kluang
# Processing Record 44 of Set 23 | kaeo
# Processing Record 45 of Set 23 | oktyabrskoye
# Processing Record 46 of Set 23 | wufeng
# Processing Record 47 of Set 23 | quesnel
# Processing Record 48 of Set 23 | hearst
# Processing Record 49 of Set 23 | borogontsy
# Processing Record 50 of Set 23 | laguna
# Processing Record 1 of Set 24 | benguela
# Processing Record 2 of Set 24 | kanchanaburi
# Processing Record 3 of Set 24 | chara
# Processing Record 4 of Set 24 | faanui
# Processing Record 5 of Set 24 | oblivskaya
# Processing Record 6 of Set 24 | barcelona
# Processing Record 7 of Set 24 | rtishchevo
# Processing Record 8 of Set 24 | cockburn town
# Processing Record 9 of Set 24 | chikwawa
# Processing Record 10 of Set 24 | dikson
# Processing Record 11 of Set 24 | ginir
# Processing Record 12 of Set 24 | tiarei
# Processing Record 13 of Set 24 | sirnak
# Processing Record 14 of Set 24 | daoukro
# Processing Record 15 of Set 24 | nanortalik
# Processing Record 16 of Set 24 | mardan
# Processing Record 17 of Set 24 | imeni telmana
# City not found. Skipping...
# Processing Record 18 of Set 24 | okato
# Processing Record 19 of Set 24 | ternate
# Processing Record 20 of Set 24 | bethel
# Processing Record 21 of Set 24 | paita
# Processing Record 22 of Set 24 | havoysund
# Processing Record 23 of Set 24 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 24 | namatanai
# Processing Record 25 of Set 24 | kahului
# Processing Record 26 of Set 24 | nijar
# Processing Record 27 of Set 24 | puqi
# Processing Record 28 of Set 24 | hudson bay
# Processing Record 29 of Set 24 | mahina
# Processing Record 30 of Set 24 | bembereke
# Processing Record 31 of Set 24 | ialibu
# Processing Record 32 of Set 24 | shipitsyno
# Processing Record 33 of Set 24 | najran
# Processing Record 34 of Set 24 | constitucion
# Processing Record 35 of Set 24 | kushima
# Processing Record 36 of Set 24 | griffith
# Processing Record 37 of Set 24 | adre
# Processing Record 38 of Set 24 | roma
# Processing Record 39 of Set 24 | sisimiut
# Processing Record 40 of Set 24 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 24 | ahipara
# Processing Record 42 of Set 24 | ballina
# Processing Record 43 of Set 24 | mount isa
# Processing Record 44 of Set 24 | pedernales
# Processing Record 45 of Set 24 | charters towers
# Processing Record 46 of Set 24 | ati
# Processing Record 47 of Set 24 | hermitage
# Processing Record 48 of Set 24 | mersing
# Processing Record 49 of Set 24 | vieux-habitants
# Processing Record 50 of Set 24 | margate
# Processing Record 1 of Set 25 | tevaitoa
# Processing Record 2 of Set 25 | karratha
# Processing Record 3 of Set 25 | batagay-alyta
# Processing Record 4 of Set 25 | cairns
# Processing Record 5 of Set 25 | uray
# Processing Record 6 of Set 25 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 25 | lasa
# Processing Record 8 of Set 25 | pontianak
# Processing Record 9 of Set 25 | alofi
# Processing Record 10 of Set 25 | umm kaddadah
# Processing Record 11 of Set 25 | muzhi
# Processing Record 12 of Set 25 | pandan
# Processing Record 13 of Set 25 | beringovskiy
# Processing Record 14 of Set 25 | cap malheureux
# Processing Record 15 of Set 25 | agha jari
# City not found. Skipping...
# Processing Record 16 of Set 25 | muisne
# Processing Record 17 of Set 25 | marsh harbour
# Processing Record 18 of Set 25 | kedrovyy
# Processing Record 19 of Set 25 | faya
# Processing Record 20 of Set 25 | siocon
# Processing Record 21 of Set 25 | lakselv
# Processing Record 22 of Set 25 | tshane
# Processing Record 23 of Set 25 | rio grande
# Processing Record 24 of Set 25 | phan thiet
# Processing Record 25 of Set 25 | mehamn
# Processing Record 26 of Set 25 | zhigalovo
# Processing Record 27 of Set 25 | vanavara
# Processing Record 28 of Set 25 | bama
# Processing Record 29 of Set 25 | alice springs
# Processing Record 30 of Set 25 | cognac
# Processing Record 31 of Set 25 | mae hong son
# Processing Record 32 of Set 25 | kirakira
# Processing Record 33 of Set 25 | omboue
# Processing Record 34 of Set 25 | jilib
# Processing Record 35 of Set 25 | clyde river
# Processing Record 36 of Set 25 | hirara
# Processing Record 37 of Set 25 | celestun
# Processing Record 38 of Set 25 | agirish
# Processing Record 39 of Set 25 | zabol
# Processing Record 40 of Set 25 | alexandria
# Processing Record 41 of Set 25 | college
# Processing Record 42 of Set 25 | nabire
# Processing Record 43 of Set 25 | zemio
# Processing Record 44 of Set 25 | onverwacht
# Processing Record 45 of Set 25 | igrim
# Processing Record 46 of Set 25 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 25 | kavaratti
# Processing Record 48 of Set 25 | nanakuli
# Processing Record 49 of Set 25 | mayumba
# Processing Record 50 of Set 25 | anadyr
# Processing Record 1 of Set 26 | sur
# Processing Record 2 of Set 26 | dzhuryn
# Processing Record 3 of Set 26 | la suiza
# Processing Record 4 of Set 26 | yanji
# Processing Record 5 of Set 26 | padang
# Processing Record 6 of Set 26 | edgewater
# Processing Record 7 of Set 26 | nagram
# Processing Record 8 of Set 26 | vila franca do campo
# Processing Record 9 of Set 26 | meridian
# Processing Record 10 of Set 26 | abalak
# Processing Record 11 of Set 26 | vila velha
# Processing Record 12 of Set 26 | mbanza-ngungu
# Processing Record 13 of Set 26 | sola
# Processing Record 14 of Set 26 | bajil
# Processing Record 15 of Set 26 | caravelas
# Processing Record 16 of Set 26 | bugyi
# Processing Record 17 of Set 26 | timiryazevskoye
# Processing Record 18 of Set 26 | general roca
# Processing Record 19 of Set 26 | virginia beach
# Processing Record 20 of Set 26 | ribeirao bonito
# Processing Record 21 of Set 26 | dicabisagan
# Processing Record 22 of Set 26 | fort nelson
# Processing Record 23 of Set 26 | straumen
# Processing Record 24 of Set 26 | odienne
# Processing Record 25 of Set 26 | palu
# Processing Record 26 of Set 26 | lagos
# Processing Record 27 of Set 26 | loukhi
# Processing Record 28 of Set 26 | sjovegan
# Processing Record 29 of Set 26 | gravdal
# Processing Record 30 of Set 26 | laramie
# Processing Record 31 of Set 26 | laukaa
# Processing Record 32 of Set 26 | coquimbo
# Processing Record 33 of Set 26 | san luis
# Processing Record 34 of Set 26 | aden
# Processing Record 35 of Set 26 | camacha
# Processing Record 36 of Set 26 | mendi
# Processing Record 37 of Set 26 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 26 | channel-port aux basques
# Processing Record 39 of Set 26 | westport
# Processing Record 40 of Set 26 | teya
# Processing Record 41 of Set 26 | auki
# Processing Record 42 of Set 26 | queenstown
# Processing Record 43 of Set 26 | lashio
# Processing Record 44 of Set 26 | coahuayana
# Processing Record 45 of Set 26 | ust-barguzin
# Processing Record 46 of Set 26 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 26 | avera
# Processing Record 48 of Set 26 | port-gentil
# Processing Record 49 of Set 26 | moroni
# Processing Record 50 of Set 26 | flagstaff
# Processing Record 1 of Set 27 | arlit
# Processing Record 2 of Set 27 | asau
# Processing Record 3 of Set 27 | lavumisa
# Processing Record 4 of Set 27 | hondo
# Processing Record 5 of Set 27 | allanridge
# Processing Record 6 of Set 27 | arrifes
# Processing Record 7 of Set 27 | comodoro rivadavia
# Processing Record 8 of Set 27 | mezhdurechensk
# Processing Record 9 of Set 27 | horta
# Processing Record 10 of Set 27 | proddatur
# Processing Record 11 of Set 27 | inta
# Processing Record 12 of Set 27 | uruzgan
# Processing Record 13 of Set 27 | bilibino
# Processing Record 14 of Set 27 | loudi
# Processing Record 15 of Set 27 | inirida
# Processing Record 16 of Set 27 | dolbeau
# City not found. Skipping...
# Processing Record 17 of Set 27 | krasnyy chikoy
# Processing Record 18 of Set 27 | viedma
# Processing Record 19 of Set 27 | nyazepetrovsk
# Processing Record 20 of Set 27 | pietersburg
# Processing Record 21 of Set 27 | vanimo
# Processing Record 22 of Set 27 | ulaangom
# Processing Record 23 of Set 27 | lososina
# Processing Record 24 of Set 27 | suzzara
# Processing Record 25 of Set 27 | daru
# Processing Record 26 of Set 27 | verkhoturye
# Processing Record 27 of Set 27 | aban
# Processing Record 28 of Set 27 | elban
# Processing Record 29 of Set 27 | ambovombe
# Processing Record 30 of Set 27 | gisborne
# Processing Record 31 of Set 27 | untsukul
# Processing Record 32 of Set 27 | santa isabel do rio negro
# Processing Record 33 of Set 27 | banda aceh
# Processing Record 34 of Set 27 | ust-kuyga
# Processing Record 35 of Set 27 | shache
# Processing Record 36 of Set 27 | eyl
# Processing Record 37 of Set 27 | vaitape
# Processing Record 38 of Set 27 | marabba
# Processing Record 39 of Set 27 | astana
# Processing Record 40 of Set 27 | victoria point
# Processing Record 41 of Set 27 | beyneu
# Processing Record 42 of Set 27 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 27 | nkhata bay
# Processing Record 44 of Set 27 | mizdah
# Processing Record 45 of Set 27 | chimore
# Processing Record 46 of Set 27 | calafell
# Processing Record 47 of Set 27 | shirokiy
# Processing Record 48 of Set 27 | elizabeth city
# Processing Record 49 of Set 27 | rondonopolis
# Processing Record 50 of Set 27 | abnub
# Processing Record 1 of Set 28 | oxford
# Processing Record 2 of Set 28 | alpena
# Processing Record 3 of Set 28 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 28 | belyy
# Processing Record 5 of Set 28 | kjollefjord
# Processing Record 6 of Set 28 | hofgeismar
# Processing Record 7 of Set 28 | rawson
# Processing Record 8 of Set 28 | pacific grove
# Processing Record 9 of Set 28 | blonduos
# City not found. Skipping...
# Processing Record 10 of Set 28 | adilcevaz
# Processing Record 11 of Set 28 | mao
# Processing Record 12 of Set 28 | lokosovo
# Processing Record 13 of Set 28 | anrochte
# Processing Record 14 of Set 28 | serra
# Processing Record 15 of Set 28 | kinkala
# Processing Record 16 of Set 28 | kimbe
# Processing Record 17 of Set 28 | telemaco borba
# Processing Record 18 of Set 28 | gweta
# Processing Record 19 of Set 28 | strezhevoy
# Processing Record 20 of Set 28 | dunedin
# Processing Record 21 of Set 28 | port shepstone
# Processing Record 22 of Set 28 | tilichiki
# Processing Record 23 of Set 28 | fatehpur
# Processing Record 24 of Set 28 | puerto escondido
# Processing Record 25 of Set 28 | shu
# Processing Record 26 of Set 28 | awjilah
# Processing Record 27 of Set 28 | san juan
# Processing Record 28 of Set 28 | taiobeiras
# Processing Record 29 of Set 28 | sovetskiy
# Processing Record 30 of Set 28 | kamenka
# Processing Record 31 of Set 28 | olafsvik
# Processing Record 32 of Set 28 | gornopravdinsk
# Processing Record 33 of Set 28 | ouadda
# Processing Record 34 of Set 28 | thoen
# Processing Record 35 of Set 28 | luderitz
# Processing Record 36 of Set 28 | lata
# Processing Record 37 of Set 28 | warwick
# Processing Record 38 of Set 28 | shihezi
# Processing Record 39 of Set 28 | cap-aux-meules
# Processing Record 40 of Set 28 | ketchenery
# City not found. Skipping...
# Processing Record 41 of Set 28 | bardiyah
# Processing Record 42 of Set 28 | shawnee
# Processing Record 43 of Set 28 | vao
# Processing Record 44 of Set 28 | inverell
# Processing Record 45 of Set 28 | collie
# Processing Record 46 of Set 28 | bonoua
# Processing Record 47 of Set 28 | tremedal
# Processing Record 48 of Set 28 | turbat
# Processing Record 49 of Set 28 | singaraja
# Processing Record 50 of Set 28 | lerwick
# Processing Record 1 of Set 29 | togur
# Processing Record 2 of Set 29 | ornskoldsvik
# Processing Record 3 of Set 29 | key west
# Processing Record 4 of Set 29 | puerto el triunfo
# Processing Record 5 of Set 29 | pitiquito
# Processing Record 6 of Set 29 | jinji
# Processing Record 7 of Set 29 | batemans bay
# Processing Record 8 of Set 29 | fort walton beach
# Processing Record 9 of Set 29 | sakakah
# Processing Record 10 of Set 29 | churapcha
# Processing Record 11 of Set 29 | katobu
# Processing Record 12 of Set 29 | sarkand
# Processing Record 13 of Set 29 | mahebourg
# Processing Record 14 of Set 29 | tamiahua
# Processing Record 15 of Set 29 | fairlie
# Processing Record 16 of Set 29 | la palma
# Processing Record 17 of Set 29 | damghan
# Processing Record 18 of Set 29 | yeppoon
# Processing Record 19 of Set 29 | jiblah
# Processing Record 20 of Set 29 | cienaga
# Processing Record 21 of Set 29 | sao joao da barra
# Processing Record 22 of Set 29 | santa rosa
# Processing Record 23 of Set 29 | neiafu
# Processing Record 24 of Set 29 | honningsvag
# Processing Record 25 of Set 29 | changying
# Processing Record 26 of Set 29 | inndyr
# Processing Record 27 of Set 29 | guerrero negro
# Processing Record 28 of Set 29 | fairbanks
# Processing Record 29 of Set 29 | quatre cocos
# Processing Record 30 of Set 29 | rio gallegos
# Processing Record 31 of Set 29 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 29 | pevek
# Processing Record 33 of Set 29 | kapit
# Processing Record 34 of Set 29 | eldikan
# City not found. Skipping...
# Processing Record 35 of Set 29 | meybod
# Processing Record 36 of Set 29 | sinnamary
# Processing Record 37 of Set 29 | nokaneng
# Processing Record 38 of Set 29 | salekhard
# Processing Record 39 of Set 29 | cascais
# Processing Record 40 of Set 29 | bubaque
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Torbay  47.6666  -52.7314     60.28        81          75
# 1       Rikitea -23.1203 -134.9692     73.40        64         100
# 2        Hobart -42.8794  147.3294     54.10        92          90
# 3     Ostrovnoy  68.0531   39.5131     44.51        87          21
# 4         Ikeda  34.8221  135.4298     71.40        84           1
# 5       Bintulu   3.1667  113.0333     75.61       100          40
# 6     Jamestown  42.0970  -79.2353     69.44        63          90
# 7  Campo Grande -20.4428  -54.6464     90.95        43          40
# 8    Lavrentiya  65.5833 -171.0000     23.27        71          16
# 9     Hithadhoo  -0.6000   73.0833     83.23        75          86
#
#    Wind Speed Country                 Date
# 0        2.30      CA  2021-10-03 18:35:31
# 1       17.65      PF  2021-10-03 18:43:13
# 2        0.00      AU  2021-10-03 18:45:16
# 3       20.83      RU  2021-10-03 18:38:23
# 4        2.91      JP  2021-10-03 18:47:37
# 5        0.00      MY  2021-10-03 18:47:37
# 6        7.00      US  2021-10-03 18:47:38
# 7       13.80      BR  2021-10-03 18:47:38
# 8        3.83      RU  2021-10-03 18:43:32
# 9       16.98      MV  2021-10-03 18:47:38

# %%
pd.options.display.float_format = "{:.2f}".format
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Torbay  47.67  -52.73     60.28        81          75        2.30
# 1       Rikitea -23.12 -134.97     73.40        64         100       17.65
# 2        Hobart -42.88  147.33     54.10        92          90        0.00
# 3     Ostrovnoy  68.05   39.51     44.51        87          21       20.83
# 4         Ikeda  34.82  135.43     71.40        84           1        2.91
# 5       Bintulu   3.17  113.03     75.61       100          40        0.00
# 6     Jamestown  42.10  -79.24     69.44        63          90        7.00
# 7  Campo Grande -20.44  -54.65     90.95        43          40       13.80
# 8    Lavrentiya  65.58 -171.00     23.27        71          16        3.83
# 9     Hithadhoo  -0.60   73.08     83.23        75          86       16.98
#
#   Country                 Date
# 0      CA  2021-10-03 18:35:31
# 1      PF  2021-10-03 18:43:13
# 2      AU  2021-10-03 18:45:16
# 3      RU  2021-10-03 18:38:23
# 4      JP  2021-10-03 18:47:37
# 5      MY  2021-10-03 18:47:37
# 6      US  2021-10-03 18:47:38
# 7      BR  2021-10-03 18:47:38
# 8      RU  2021-10-03 18:43:32
# 9      MV  2021-10-03 18:47:38

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
